# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from datetime import datetime

# %%
df_emailopened = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September272023/Wednesday-27-September-EmailOpened.csv")

df_emailsends = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September272023/Wednesday-27-September-EmailSends.csv")

df_clicksFreshersFairdayone = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September272023/Wednesday-27-September-Link-clicksFreshers' Fair day one.csv")

df_clicksglobalcafe = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September272023/Wednesday-27-September-Link-clicksglobal cafe.csv")

df_clicksmovie = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September272023/Wednesday-27-September-Link-clicksmovie.csv")

df_recepient_clickslink = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September272023/Wednesday-27-September-Recipient-clickslink.csv")

# %%
df_emailopened.head()
# Out:
#    NumOpens                   Email EmailType        DateOpened  \
# 0         1   ucn1@student.le.ac.uk      Html  27/09/2023 09:27
# 1         1  jg562@student.le.ac.uk      Html  25/10/2023 17:09
# 2         1   vdg2@student.le.ac.uk      Html  27/09/2023 09:21
# 3         1  dcc26@student.le.ac.uk      Html  27/09/2023 09:20
# 4         1  arc39@student.le.ac.uk      Html  08/11/2023 17:31
#
#      DateOpenedLast
# 0  27/09/2023 09:27
# 1  25/10/2023 17:09
# 2  27/09/2023 09:21
# 3  27/09/2023 09:20
# 4  08/11/2023 17:31

# %%
df_emailsends.value_counts()
# Out:
# Email                    DateSent          Firstname  Lastname  EmailType
# a1033@student.le.ac.uk   27/09/2023 09:18  Unknown    Unknown   Html         1
# nsmsha1@leicester.ac.uk  27/09/2023 09:18  Unknown    Unknown   Html         1
# nsrs1@student.le.ac.uk   27/09/2023 09:18  Unknown    Unknown   Html         1
# nsr12@student.le.ac.uk   27/09/2023 09:18  Unknown    Unknown   Html         1
# nsp19@student.le.ac.uk   27/09/2023 09:18  Unknown    Unknown   Html         1
#                                                                             ..
# hfyad2@leicester.ac.uk   27/09/2023 09:18  Unknown    Unknown   Html         1
# hfsl1@student.le.ac.uk   27/09/2023 09:18  Unknown    Unknown   Html         1
# hfp5@student.le.ac.uk    27/09/2023 09:18  Unknown    Unknown   Html         1
# hfn3@leicester.ac.uk     27/09/2023 09:18  Unknown    Unknown   Html         1
# zz306@student.le.ac.uk   27/09/2023 09:18  Unknown    Unknown   Html         1
# Length: 26010, dtype: int64

# %%
df_emailopened.duplicated().sum()
# Out:
# 0

# %%
df_emailopened.isnull().sum()
# Out:
# NumOpens          0
# Email             0
# EmailType         0
# DateOpened        0
# DateOpenedLast    0
# dtype: int64

# %%
df_emailsends.head()
# Out:
#                     Email          DateSent Firstname Lastname EmailType
# 0   ucn1@student.le.ac.uk  27/09/2023 09:18       NaN      NaN      Html
# 1  jlpc1@student.le.ac.uk  27/09/2023 09:18       NaN      NaN      Html
# 2  jg562@student.le.ac.uk  27/09/2023 09:18       NaN      NaN      Html
# 3   vdg2@student.le.ac.uk  27/09/2023 09:18       NaN      NaN      Html
# 4  dcc26@student.le.ac.uk  27/09/2023 09:18       NaN      NaN      Html

# %%
df_emailsends.duplicated().sum()
# Out:
# 0

# %%
df_emailsends.isnull().sum()
# Out:
# Email            0
# DateSent         0
# Firstname    25006
# Lastname     25101
# EmailType        0
# dtype: int64

# %%
df_emailsends['Firstname'] = df_emailsends['Firstname'].fillna('Unknown')
df_emailsends['Lastname'] = df_emailsends['Lastname'].fillna('Unknown')
df_emailsends
# Out:
#                         Email          DateSent Firstname Lastname EmailType
# 0       ucn1@student.le.ac.uk  27/09/2023 09:18   Unknown  Unknown      Html
# 1      jlpc1@student.le.ac.uk  27/09/2023 09:18   Unknown  Unknown      Html
# 2      jg562@student.le.ac.uk  27/09/2023 09:18   Unknown  Unknown      Html
# 3       vdg2@student.le.ac.uk  27/09/2023 09:18   Unknown  Unknown      Html
# 4      dcc26@student.le.ac.uk  27/09/2023 09:18   Unknown  Unknown      Html
# ...                       ...               ...       ...      ...       ...
# 26005   ma880@leicester.ac.uk  27/09/2023 09:18   Unknown  Unknown      Html
# 26006    rnk8@leicester.ac.uk  27/09/2023 09:18   Unknown  Unknown      Html
# 26007   wiha1@leicester.ac.uk  27/09/2023 09:18   Unknown  Unknown      Html
# 26008         advice@le.ac.uk  27/09/2023 09:18   Unknown  Unknown      Html
# 26009     coursereps@le.ac.uk  27/09/2023 09:18   Unknown  Unknown      Html
#
# [26010 rows x 5 columns]

# %%
df_clicksFreshersFairdayone.head()
# Out:
#    NumClicks  NumClicks.1                    Email EmailType Firstname  \
# 0          1            1   xz342@student.le.ac.uk      Html       NaN
# 1          1            1   aam54@student.le.ac.uk      Html       NaN
# 2          1            1  sm1039@student.le.ac.uk      Html       NaN
# 3          1            1     ya81@leicester.ac.uk      Html       NaN
# 4          1            1     qj12@leicester.ac.uk      Html    Qishan
#
#   Lastname
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4    Jiang

# %%
df_clicksFreshersFairdayone.duplicated().sum()
# Out:
# 0

# %%
df_clicksFreshersFairdayone.isnull().sum()
# Out:
# NumClicks        0
# NumClicks.1      0
# Email            0
# EmailType        0
# Firstname      298
# Lastname       300
# dtype: int64

# %%
df_clicksFreshersFairdayone["Firstname"] = df_clicksFreshersFairdayone["Firstname"].fillna("Unknown")
df_clicksFreshersFairdayone["Lastname"] = df_clicksFreshersFairdayone["Lastname"].fillna("Unknown")
df_clicksFreshersFairdayone
# Out:
#      NumClicks  NumClicks.1                    Email EmailType Firstname  \
# 0            1            1   xz342@student.le.ac.uk      Html   Unknown
# 1            1            1   aam54@student.le.ac.uk      Html   Unknown
# 2            1            1  sm1039@student.le.ac.uk      Html   Unknown
# 3            1            1     ya81@leicester.ac.uk      Html   Unknown
# 4            1            1     qj12@leicester.ac.uk      Html    Qishan
# ..         ...          ...                      ...       ...       ...
# 299          1            1   ia255@student.le.ac.uk      Html   Unknown
# 300          1            1   am1412@leicester.ac.uk      Html   Unknown
# 301          1            1   sppda2@leicester.ac.uk      Html   Unknown
# 302          1            1   si188@student.le.ac.uk      Html   Unknown
# 303          1            1    zh169@leicester.ac.uk      Html  Zulfikar
#
#     Lastname
# 0    Unknown
# 1    Unknown
# 2    Unknown
# 3    Unknown
# 4      Jiang
# ..       ...
# 299  Unknown
# 300  Unknown
# 301  Unknown
# 302  Unknown
# 303   Hanafi
#
# [304 rows x 6 columns]

# %%
df_clicksglobalcafe.head()
# Out:
#    NumClicks  NumClicks.1                   Email EmailType Firstname Lastname
# 0          1            1    ya81@leicester.ac.uk      Html       NaN      NaN
# 1          1            1   blj5@student.le.ac.uk      Html       NaN      NaN
# 2          1            1  yl691@student.le.ac.uk      Html       NaN      NaN
# 3          1            1  ibhs1@student.le.ac.uk      Html       NaN      NaN
# 4          1            1   ky102@leicester.ac.uk      Html       NaN      NaN

# %%
df_clicksglobalcafe.duplicated().sum()
# Out:
# 0

# %%
df_clicksglobalcafe.isnull().sum()
# Out:
# NumClicks       0
# NumClicks.1     0
# Email           0
# EmailType       0
# Firstname      74
# Lastname       74
# dtype: int64

# %%
df_clicksglobalcafe["Firstname"] = df_clicksglobalcafe["Firstname"].fillna("Unknown")
df_clicksglobalcafe["Lastname"] = df_clicksglobalcafe["Lastname"].fillna("Unknown")
df_clicksglobalcafe
# Out:
#     NumClicks  NumClicks.1                    Email EmailType Firstname  \
# 0           1            1     ya81@leicester.ac.uk      Html   Unknown
# 1           1            1    blj5@student.le.ac.uk      Html   Unknown
# 2           1            1   yl691@student.le.ac.uk      Html   Unknown
# 3           1            1   ibhs1@student.le.ac.uk      Html   Unknown
# 4           1            1    ky102@leicester.ac.uk      Html   Unknown
# ..        ...          ...                      ...       ...       ...
# 70          1            1   sd591@student.le.ac.uk      Html   Unknown
# 71          1            1   yp116@student.le.ac.uk      Html   Unknown
# 72          1            1    dhh3@student.le.ac.uk      Html   Unknown
# 73          1            1   ehcm1@student.le.ac.uk      Html   Unknown
# 74          1            1  alsag1@student.le.ac.uk      Html   Unknown
#
#    Lastname
# 0   Unknown
# 1   Unknown
# 2   Unknown
# 3   Unknown
# 4   Unknown
# ..      ...
# 70  Unknown
# 71  Unknown
# 72  Unknown
# 73  Unknown
# 74  Unknown
#
# [75 rows x 6 columns]

# %%
df_clicksmovie.head()
# Out:
#    NumClicks  NumClicks.1                    Email EmailType Firstname  \
# 0          1            1  mm1084@student.le.ac.uk      Html       NaN
# 1          1            1     ncv6@leicester.ac.uk      Html       NaN
# 2          1            1    gel6@student.le.ac.uk      Html       NaN
# 3          1            1  ajs126@student.le.ac.uk      Html       NaN
# 4          1            1    zrb1@student.le.ac.uk      Html       NaN
#
#   Lastname
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
df_clicksmovie.duplicated().sum()
# Out:
# 0

# %%
df_clicksmovie.isnull().sum()
# Out:
# NumClicks        0
# NumClicks.1      0
# Email            0
# EmailType        0
# Firstname      176
# Lastname       178
# dtype: int64

# %%
df_clicksmovie["Firstname"] = df_clicksmovie["Firstname"].fillna("Unknown")
df_clicksmovie["Lastname"] = df_clicksmovie["Lastname"].fillna("Unknown")
df_clicksmovie
# Out:
#      NumClicks  NumClicks.1                    Email EmailType Firstname  \
# 0            1            1  mm1084@student.le.ac.uk      Html   Unknown
# 1            1            1     ncv6@leicester.ac.uk      Html   Unknown
# 2            1            1    gel6@student.le.ac.uk      Html   Unknown
# 3            1            1  ajs126@student.le.ac.uk      Html   Unknown
# 4            1            1    zrb1@student.le.ac.uk      Html   Unknown
# ..         ...          ...                      ...       ...       ...
# 178          1            1    re134@leicester.ac.uk      Html   Unknown
# 179          1            1    zh169@leicester.ac.uk      Html  Zulfikar
# 180          1            1   sz267@student.le.ac.uk      Html   Unknown
# 181          1            1  alsag1@student.le.ac.uk      Html   Unknown
# 182          1            1     lao9@leicester.ac.uk      Html      Lola
#
#      Lastname
# 0     Unknown
# 1     Unknown
# 2     Unknown
# 3     Unknown
# 4     Unknown
# ..        ...
# 178   Unknown
# 179    Hanafi
# 180   Unknown
# 181   Unknown
# 182  Abs Osta
#
# [183 rows x 6 columns]

# %%
df_recepient_clickslink.head()
# Out:
#                      Email  Html  \
# 0    vdj4@student.le.ac.uk  True
# 1    rds30@leicester.ac.uk  True
# 2  mm1084@student.le.ac.uk  True
# 3     ncv6@leicester.ac.uk  True
# 4  ss1544@student.le.ac.uk  True
#
#                                                  Url       DateClicked  \
# 0           https://www.instagram.com/p/CxXyacOtF_X/  27/09/2023 10:03
# 1           https://www.instagram.com/p/CxXyacOtF_X/  27/09/2023 13:32
# 2  https://www.eventbrite.com/e/film-night-the-su...  27/09/2023 09:20
# 3  https://www.eventbrite.com/e/film-night-the-su...  27/09/2023 11:33
# 4                    https://le.ac.uk/study/welcome/  27/09/2023 09:35
#
#                                            UserAgent              IP  \
# 0  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...    104.129.16.8
# 1  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...  143.210.250.96
# 2  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...  143.210.250.96
# 3  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...  143.210.250.96
# 4  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   202.209.25.66
#
#      Keyword  LinkGroups
# 0  wellbeing         NaN
# 1  wellbeing         NaN
# 2      movie         NaN
# 3      movie         NaN
# 4        NaN         NaN

# %%
df_recepient_clickslink.duplicated().sum()
# Out:
# 17

# %%
df_recepient_clickslink.drop_duplicates()
# Out:
#                        Email  Html  \
# 0      vdj4@student.le.ac.uk  True
# 1      rds30@leicester.ac.uk  True
# 2    mm1084@student.le.ac.uk  True
# 3       ncv6@leicester.ac.uk  True
# 4    ss1544@student.le.ac.uk  True
# ..                       ...   ...
# 829  alsag1@student.le.ac.uk  True
# 830   aea22@student.le.ac.uk  True
# 831   smza2@student.le.ac.uk  True
# 832    kki2@student.le.ac.uk  True
# 833     lao9@leicester.ac.uk  True
#
#                                                    Url       DateClicked  \
# 0             https://www.instagram.com/p/CxXyacOtF_X/  27/09/2023 10:03
# 1             https://www.instagram.com/p/CxXyacOtF_X/  27/09/2023 13:32
# 2    https://www.eventbrite.com/e/film-night-the-su...  27/09/2023 09:20
# 3    https://www.eventbrite.com/e/film-night-the-su...  27/09/2023 11:33
# 4                      https://le.ac.uk/study/welcome/  27/09/2023 09:35
# ..                                                 ...               ...
# 829              https://le.ac.uk/study/welcome/events  27/09/2023 11:16
# 830         https://www.instagram.com/leicstudentlife/  27/09/2023 16:20
# 831  https://reslife.le.ac.uk/wellbeing-wednesday_1...  27/09/2023 10:23
# 832         https://www.instagram.com/leicstudentlife/  27/09/2023 09:20
# 833  https://www.eventbrite.com/e/film-night-the-su...  27/09/2023 13:52
#
#                                              UserAgent               IP  \
# 0    Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...     104.129.16.8
# 1    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...   143.210.250.96
# 2    Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...   143.210.250.96
# 3    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...   143.210.250.96
# 4    Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...    202.209.25.66
# ..                                                 ...              ...
# 829  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...     86.135.3.218
# 830  Mozilla/5.0 (iPhone; CPU iPhone OS 17_0 like M...   90.217.220.125
# 831  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...    5.151.227.243
# 832  Mozilla/5.0 (iPhone; CPU iPhone OS 16_6 like M...       5.2.123.67
# 833  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  195.213.199.169
#
#             Keyword  LinkGroups
# 0         wellbeing         NaN
# 1         wellbeing         NaN
# 2             movie         NaN
# 3             movie         NaN
# 4               NaN         NaN
# ..              ...         ...
# 829     global cafe         NaN
# 830    social media         NaN
# 831  wellbeing weds         NaN
# 832    social media         NaN
# 833           movie         NaN
#
# [817 rows x 8 columns]

# %%
df_recepient_clickslink.isnull().sum()
# Out:
# Email            0
# Html             0
# Url              0
# DateClicked      0
# UserAgent        0
# IP               0
# Keyword         40
# LinkGroups     834
# dtype: int64

# %%
df_recepient_clickslink["Keyword"] = df_recepient_clickslink["Keyword"].fillna("Unknown")
df_recepient_clickslink["LinkGroups"] = df_recepient_clickslink["LinkGroups"].fillna("Unknown")
df_recepient_clickslink
# Out:
#                        Email  Html  \
# 0      vdj4@student.le.ac.uk  True
# 1      rds30@leicester.ac.uk  True
# 2    mm1084@student.le.ac.uk  True
# 3       ncv6@leicester.ac.uk  True
# 4    ss1544@student.le.ac.uk  True
# ..                       ...   ...
# 829  alsag1@student.le.ac.uk  True
# 830   aea22@student.le.ac.uk  True
# 831   smza2@student.le.ac.uk  True
# 832    kki2@student.le.ac.uk  True
# 833     lao9@leicester.ac.uk  True
#
#                                                    Url       DateClicked  \
# 0             https://www.instagram.com/p/CxXyacOtF_X/  27/09/2023 10:03
# 1             https://www.instagram.com/p/CxXyacOtF_X/  27/09/2023 13:32
# 2    https://www.eventbrite.com/e/film-night-the-su...  27/09/2023 09:20
# 3    https://www.eventbrite.com/e/film-night-the-su...  27/09/2023 11:33
# 4                      https://le.ac.uk/study/welcome/  27/09/2023 09:35
# ..                                                 ...               ...
# 829              https://le.ac.uk/study/welcome/events  27/09/2023 11:16
# 830         https://www.instagram.com/leicstudentlife/  27/09/2023 16:20
# 831  https://reslife.le.ac.uk/wellbeing-wednesday_1...  27/09/2023 10:23
# 832         https://www.instagram.com/leicstudentlife/  27/09/2023 09:20
# 833  https://www.eventbrite.com/e/film-night-the-su...  27/09/2023 13:52
#
#                                              UserAgent               IP  \
# 0    Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...     104.129.16.8
# 1    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...   143.210.250.96
# 2    Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...   143.210.250.96
# 3    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...   143.210.250.96
# 4    Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...    202.209.25.66
# ..                                                 ...              ...
# 829  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...     86.135.3.218
# 830  Mozilla/5.0 (iPhone; CPU iPhone OS 17_0 like M...   90.217.220.125
# 831  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...    5.151.227.243
# 832  Mozilla/5.0 (iPhone; CPU iPhone OS 16_6 like M...       5.2.123.67
# 833  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  195.213.199.169
#
#             Keyword LinkGroups
# 0         wellbeing    Unknown
# 1         wellbeing    Unknown
# 2             movie    Unknown
# 3             movie    Unknown
# 4           Unknown    Unknown
# ..              ...        ...
# 829     global cafe    Unknown
# 830    social media    Unknown
# 831  wellbeing weds    Unknown
# 832    social media    Unknown
# 833           movie    Unknown
#
# [834 rows x 8 columns]

# %%
def total_opens():
    total_opens = df_emailopened["NumOpens"].sum()
    print("Total number of NumOpens: ", total_opens)



total_opens()
# Out:
# Total number of NumOpens:  25030

# %%
average_opens = df_emailopened["NumOpens"].mean()
df_emailopened["AverageNumOpens"] = average_opens

print("Average number of NumOpens:", average_opens)
# Out:
# Average number of NumOpens: 2.040766408479413

# %%
minimum_opens = df_emailopened["NumOpens"].min()
df_emailopened["MinimumOpens"] = minimum_opens
print("Minimum number of NumOpens: ", minimum_opens)
# Out:
# Minimum number of NumOpens:  1

# %%
maximum_opens = df_emailopened["NumOpens"].max()
df_emailopened["MaximumOpens"] = maximum_opens
print("Maximum number of NumOpens: ", maximum_opens)
# Out:
# Maximum number of NumOpens:  32

# %%
df_emailopened["DateOpened"] = pd.to_datetime(df_emailopened["DateOpened"], format="%d/%m/%Y %H:%M") #convert string to datetime

# %%
df_emailopened["DateOpenedLast"] = pd.to_datetime(df_emailopened["DateOpenedLast"], format="%d/%m/%Y %H:%M") #convert string to datetime

# %%
df_emailopened["EngagementSpan"] = df_emailopened["DateOpenedLast"] - df_emailopened["DateOpened"]
df_emailopened.head(10)
# Out:
#    NumOpens                    Email EmailType          DateOpened  \
# 0         1    ucn1@student.le.ac.uk      Html 2023-09-27 09:27:00
# 1         1   jg562@student.le.ac.uk      Html 2023-10-25 17:09:00
# 2         1    vdg2@student.le.ac.uk      Html 2023-09-27 09:21:00
# 3         1   dcc26@student.le.ac.uk      Html 2023-09-27 09:20:00
# 4         1   arc39@student.le.ac.uk      Html 2023-11-08 17:31:00
# 5         2    zgp2@student.le.ac.uk      Html 2023-09-27 14:11:00
# 6         4   shia1@student.le.ac.uk      Html 2023-09-27 10:02:00
# 7         2   jarf1@student.le.ac.uk      Html 2023-09-27 13:33:00
# 8         1   cll46@student.le.ac.uk      Html 2023-09-29 09:15:00
# 9         1  ajp120@student.le.ac.uk      Html 2023-10-01 17:12:00
#
#        DateOpenedLast  AverageNumOpens  MinimumOpens  MaximumOpens  \
# 0 2023-09-27 09:27:00         2.040766             1            32
# 1 2023-10-25 17:09:00         2.040766             1            32
# 2 2023-09-27 09:21:00         2.040766             1            32
# 3 2023-09-27 09:20:00         2.040766             1            32
# 4 2023-11-08 17:31:00         2.040766             1            32
# 5 2023-09-27 14:11:00         2.040766             1            32
# 6 2023-09-28 12:48:00         2.040766             1            32
# 7 2023-09-27 13:33:00         2.040766             1            32
# 8 2023-09-29 09:15:00         2.040766             1            32
# 9 2023-10-01 17:12:00         2.040766             1            32
#
#    EngagementSpan
# 0 0 days 00:00:00
# 1 0 days 00:00:00
# 2 0 days 00:00:00
# 3 0 days 00:00:00
# 4 0 days 00:00:00
# 5 0 days 00:00:00
# 6 1 days 02:46:00
# 7 0 days 00:00:00
# 8 0 days 00:00:00
# 9 0 days 00:00:00

# %%
df_emailopened["EngagementHours"] = df_emailopened["EngagementSpan"].dt.total_seconds() / 3600
df_emailopened
# Out:
#        NumOpens                   Email EmailType          DateOpened  \
# 0             1   ucn1@student.le.ac.uk      Html 2023-09-27 09:27:00
# 1             1  jg562@student.le.ac.uk      Html 2023-10-25 17:09:00
# 2             1   vdg2@student.le.ac.uk      Html 2023-09-27 09:21:00
# 3             1  dcc26@student.le.ac.uk      Html 2023-09-27 09:20:00
# 4             1  arc39@student.le.ac.uk      Html 2023-11-08 17:31:00
# ...         ...                     ...       ...                 ...
# 12260         2   kh370@leicester.ac.uk      Html 2023-09-27 09:20:00
# 12261         1   ma880@leicester.ac.uk      Html 2023-09-27 23:13:00
# 12262         1   wiha1@leicester.ac.uk      Html 2023-09-28 07:47:00
# 12263        14         advice@le.ac.uk      Html 2023-09-27 13:12:00
# 12264         1     coursereps@le.ac.uk      Html 2023-09-27 10:58:00
#
#            DateOpenedLast  AverageNumOpens  MinimumOpens  MaximumOpens  \
# 0     2023-09-27 09:27:00         2.040766             1            32
# 1     2023-10-25 17:09:00         2.040766             1            32
# 2     2023-09-27 09:21:00         2.040766             1            32
# 3     2023-09-27 09:20:00         2.040766             1            32
# 4     2023-11-08 17:31:00         2.040766             1            32
# ...                   ...              ...           ...           ...
# 12260 2023-09-27 09:20:00         2.040766             1            32
# 12261 2023-09-27 23:13:00         2.040766             1            32
# 12262 2023-09-28 07:47:00         2.040766             1            32
# 12263 2023-10-12 11:59:00         2.040766             1            32
# 12264 2023-09-27 10:58:00         2.040766             1            32
#
#         EngagementSpan  EngagementHours
# 0      0 days 00:00:00         0.000000
# 1      0 days 00:00:00         0.000000
# 2      0 days 00:00:00         0.000000
# 3      0 days 00:00:00         0.000000
# 4      0 days 00:00:00         0.000000
# ...                ...              ...
# 12260  0 days 00:00:00         0.000000
# 12261  0 days 00:00:00         0.000000
# 12262  0 days 00:00:00         0.000000
# 12263 14 days 22:47:00       358.783333
# 12264  0 days 00:00:00         0.000000
#
# [12265 rows x 10 columns]

# %%
def numopen_level_classification(opens): #categorising open levels into different categories
    if opens <= 1:
        return 'Low'
    elif opens <= 4:
        return 'Medium'
    else:
        return 'High'

# %%
df_emailopened["Openlevel"] = df_emailopened["NumOpens"].apply(numopen_level_classification)
df_emailopened
# Out:
#        NumOpens                   Email EmailType          DateOpened  \
# 0             1   ucn1@student.le.ac.uk      Html 2023-09-27 09:27:00
# 1             1  jg562@student.le.ac.uk      Html 2023-10-25 17:09:00
# 2             1   vdg2@student.le.ac.uk      Html 2023-09-27 09:21:00
# 3             1  dcc26@student.le.ac.uk      Html 2023-09-27 09:20:00
# 4             1  arc39@student.le.ac.uk      Html 2023-11-08 17:31:00
# ...         ...                     ...       ...                 ...
# 12260         2   kh370@leicester.ac.uk      Html 2023-09-27 09:20:00
# 12261         1   ma880@leicester.ac.uk      Html 2023-09-27 23:13:00
# 12262         1   wiha1@leicester.ac.uk      Html 2023-09-28 07:47:00
# 12263        14         advice@le.ac.uk      Html 2023-09-27 13:12:00
# 12264         1     coursereps@le.ac.uk      Html 2023-09-27 10:58:00
#
#            DateOpenedLast  AverageNumOpens  MinimumOpens  MaximumOpens  \
# 0     2023-09-27 09:27:00         2.040766             1            32
# 1     2023-10-25 17:09:00         2.040766             1            32
# 2     2023-09-27 09:21:00         2.040766             1            32
# 3     2023-09-27 09:20:00         2.040766             1            32
# 4     2023-11-08 17:31:00         2.040766             1            32
# ...                   ...              ...           ...           ...
# 12260 2023-09-27 09:20:00         2.040766             1            32
# 12261 2023-09-27 23:13:00         2.040766             1            32
# 12262 2023-09-28 07:47:00         2.040766             1            32
# 12263 2023-10-12 11:59:00         2.040766             1            32
# 12264 2023-09-27 10:58:00         2.040766             1            32
#
#         EngagementSpan  EngagementHours Openlevel
# 0      0 days 00:00:00         0.000000       Low
# 1      0 days 00:00:00         0.000000       Low
# 2      0 days 00:00:00         0.000000       Low
# 3      0 days 00:00:00         0.000000       Low
# 4      0 days 00:00:00         0.000000       Low
# ...                ...              ...       ...
# 12260  0 days 00:00:00         0.000000    Medium
# 12261  0 days 00:00:00         0.000000       Low
# 12262  0 days 00:00:00         0.000000       Low
# 12263 14 days 22:47:00       358.783333      High
# 12264  0 days 00:00:00         0.000000       Low
#
# [12265 rows x 11 columns]

# %%
df_emailopened["Openlevel"].value_counts().plot(kind='bar', title='Email Engagement Levels')
plt.ylabel("Number of People")
plt.show()
df_emailopened["Openlevel"].value_counts()
#high levels of medium open level
#low levels of high open level
# Out:
# Medium    7196
# Low       4542
# High       527
# Name: Openlevel, dtype: int64

# %%
df_emailopened.groupby("EmailType")["AverageNumOpens"].mean().plot(kind="bar", title="Average Opens per Email Type")
plt.ylabel("Average Opens")
plt.show()
df_emailopened.groupby("EmailType")["AverageNumOpens"].value_counts()
# Out:
# EmailType  AverageNumOpens
# Html       2.040766           12265
# Name: AverageNumOpens, dtype: int64

# %%
bins = pd.cut(df_emailopened['EngagementHours'], bins=10).value_counts().sort_index()
print(bins)

df_emailopened['EngagementHours'].plot(kind='hist', bins=10, title='Distribution of Engagement Hours')
plt.show()
# Out:
# (-15.128, 1512.753]       12017
# (1512.753, 3025.507]        105
# (3025.507, 4538.26]          40
# (4538.26, 6051.013]          32
# (6051.013, 7563.767]         18
# (7563.767, 9076.52]          22
# (9076.52, 10589.273]         11
# (10589.273, 12102.027]        9
# (12102.027, 13614.78]         8
# (13614.78, 15127.533]         3
# Name: EngagementHours, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(
    x='Openlevel',
    y='EngagementHours',
    data=df_emailopened,
    boxprops=dict(facecolor='white', edgecolor='black'),
    whiskerprops=dict(color='black'),
    capprops=dict(color='black'),
    medianprops=dict(color='black'),
    flierprops=dict(marker='o', color='black', alpha=0.3, markersize=3),
    showfliers=True
)

plt.yscale('log')  #log scale to handle skewed data
plt.title('Engagement Span by Open Level (Log Scale)')
plt.grid(True, which="both", axis='y', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

sns.boxplot(x='Openlevel', y='EngagementHours', data=df_emailopened).set_title('Engagement Span by Open Level')


df_emailopened.groupby("Openlevel")["EngagementHours"].std()
# Out:
# Openlevel
# High      1967.634921
# Low          0.000000
# Medium     931.493782
# Name: EngagementHours, dtype: float64

# %%
##most and least clicked links

def total_clicks():
    total_clicksFreshersFairdayone = df_clicksFreshersFairdayone["NumClicks"].sum()
    print("Total number of NumClicks for https://www.leicesterunion.com/events/6013/4962/: ", total_clicksFreshersFairdayone)
    
    total_clicksglobalcafe = df_clicksglobalcafe["NumClicks"].sum()
    print("Total number of NumClicks for https://le.ac.uk/study/welcome/events: ", total_clicksglobalcafe)
    

    total_clicksmovie = df_clicksmovie["NumClicks"].sum()
    print("Total number of NumClicks for https://www.eventbrite.com/e/film-night-the-super-mario-bros-movie-tickets-703189066427?aff=odcleoeventsincollection&keep_tld=1: ", total_clicksmovie)
    

    
    
    
total_clicks()
# Out:
# Total number of NumClicks for https://www.leicesterunion.com/events/6013/4962/:  366
# Total number of NumClicks for https://le.ac.uk/study/welcome/events:  89
# Total number of NumClicks for https://www.eventbrite.com/e/film-night-the-super-mario-bros-movie-tickets-703189066427?aff=odcleoeventsincollection&keep_tld=1:  203
