# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from datetime import datetime

# %%
df_emailopened = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September292023/Friday-29-September-EmailOpened.csv")

df_emailsends = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September292023/Friday-29-September-EmailSends.csv")

df_clicksautumnfest = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September292023/Friday-29-September-Link-clicksautunmfest.csv")

df_clicksBHM23 = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September292023/Friday-29-September-Link-clicksBHM23.csv")

df_clicksWellbeingday = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September292023/Friday-29-September-Link-clicksWellbeing day.csv")

df_recepient_clickslink = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September292023/Friday-29-September-Recipient-clickslink.csv")

# %%
df_emailopened.head()
# Out:
#    NumOpens                   Email EmailType        DateOpened  \
# 0         2   ucn1@student.le.ac.uk      Html  02/10/2023 16:35
# 1         2  jlpc1@student.le.ac.uk      Html  15/10/2023 18:06
# 2         1  jg562@student.le.ac.uk      Html  25/10/2023 17:08
# 3         1   vdg2@student.le.ac.uk      Html  29/09/2023 17:23
# 4         1  dcc26@student.le.ac.uk      Html  29/09/2023 13:33
#
#      DateOpenedLast
# 0  02/10/2023 16:35
# 1  15/10/2023 18:06
# 2  25/10/2023 17:08
# 3  29/09/2023 17:23
# 4  29/09/2023 13:33

# %%
df_emailsends.value_counts()
# Out:
# Email                   DateSent          Firstname  Lastname  EmailType
# a1033@student.le.ac.uk  29/09/2023 10:51  Unknown    Unknown   Html         1
# nt220@student.le.ac.uk  29/09/2023 10:51  Unknown    Unknown   Html         1
# nt235@student.le.ac.uk  29/09/2023 09:51  Unknown    Unknown   Html         1
# nt229@leicester.ac.uk   29/09/2023 10:51  Unknown    Unknown   Html         1
# nt228@student.le.ac.uk  29/09/2023 10:51  Unknown    Unknown   Html         1
#                                                                            ..
# hgp10@student.le.ac.uk  29/09/2023 09:51  Unknown    Unknown   Html         1
# hgn2@leicester.ac.uk    29/09/2023 09:51  Unknown    Unknown   Html         1
# hgm9@student.le.ac.uk   29/09/2023 10:51  Unknown    Unknown   Html         1
# hgk4@student.le.ac.uk   29/09/2023 10:51  Unknown    Unknown   Html         1
# zz308@student.le.ac.uk  29/09/2023 09:51  Unknown    Unknown   Html         1
# Length: 26252, dtype: int64

# %%
df_emailopened.duplicated().sum()
# Out:
# 0

# %%
df_emailopened.isnull().sum()
# Out:
# NumOpens          0
# Email             0
# EmailType         0
# DateOpened        0
# DateOpenedLast    0
# dtype: int64

# %%
df_emailsends.head()
# Out:
#                     Email          DateSent Firstname Lastname EmailType
# 0   ucn1@student.le.ac.uk  29/09/2023 09:51       NaN      NaN      Html
# 1  jlpc1@student.le.ac.uk  29/09/2023 09:51       NaN      NaN      Html
# 2  jg562@student.le.ac.uk  29/09/2023 09:51       NaN      NaN      Html
# 3   vdg2@student.le.ac.uk  29/09/2023 09:51       NaN      NaN      Html
# 4  dcc26@student.le.ac.uk  29/09/2023 09:51       NaN      NaN      Html

# %%
df_emailsends.duplicated().sum()
# Out:
# 0

# %%
df_emailsends.isnull().sum()
# Out:
# Email            0
# DateSent         0
# Firstname    25248
# Lastname     25343
# EmailType        0
# dtype: int64

# %%
df_emailsends["Firstname"] = df_emailsends["Firstname"].fillna("Unknown")
df_emailsends["Lastname"] = df_emailsends["Lastname"].fillna("Unknown")
df_emailsends
# Out:
#                         Email          DateSent Firstname Lastname EmailType
# 0       ucn1@student.le.ac.uk  29/09/2023 09:51   Unknown  Unknown      Html
# 1      jlpc1@student.le.ac.uk  29/09/2023 09:51   Unknown  Unknown      Html
# 2      jg562@student.le.ac.uk  29/09/2023 09:51   Unknown  Unknown      Html
# 3       vdg2@student.le.ac.uk  29/09/2023 09:51   Unknown  Unknown      Html
# 4      dcc26@student.le.ac.uk  29/09/2023 09:51   Unknown  Unknown      Html
# ...                       ...               ...       ...      ...       ...
# 26247   ma880@leicester.ac.uk  29/09/2023 10:51   Unknown  Unknown      Html
# 26248    rnk8@leicester.ac.uk  29/09/2023 10:51   Unknown  Unknown      Html
# 26249   wiha1@leicester.ac.uk  29/09/2023 10:51   Unknown  Unknown      Html
# 26250         advice@le.ac.uk  29/09/2023 10:51   Unknown  Unknown      Html
# 26251     coursereps@le.ac.uk  29/09/2023 10:51   Unknown  Unknown      Html
#
# [26252 rows x 5 columns]

# %%
df_clicksautunmfest.head()
# Out:
#    NumClicks  NumClicks.1                   Email EmailType Firstname Lastname
# 0          1            1  rb532@student.le.ac.uk      Html   Unknown  Unknown
# 1          1            1  ts364@student.le.ac.uk      Html   Unknown  Unknown
# 2          1            1   dk266@leicester.ac.uk      Html     Didem   Karaer
# 3          1            1  smt49@student.le.ac.uk      Html   Unknown  Unknown
# 4          1            1  mss46@student.le.ac.uk      Html   Unknown  Unknown

# %%
df_clicksautumnfest.duplicated().sum()
# Out:
# 0

# %%
df_clicksautumnfest.isnull().sum()
# Out:
# NumClicks       0
# NumClicks.1     0
# Email           0
# EmailType       0
# Firstname      62
# Lastname       63
# dtype: int64

# %%
df_clicksautumnfest["Firstname"] = df_clicksautumnfest["Firstname"].fillna("Unknown")
df_clicksautumnfest["Lastname"] = df_clicksautumnfest["Lastname"].fillna("Unknown")
df_clicksautumnfest
# Out:
#     NumClicks  NumClicks.1                   Email EmailType Firstname  \
# 0           1            1  rb532@student.le.ac.uk      Html   Unknown
# 1           1            1  ts364@student.le.ac.uk      Html   Unknown
# 2           1            1   dk266@leicester.ac.uk      Html     Didem
# 3           1            1  smt49@student.le.ac.uk      Html   Unknown
# 4           1            1  mss46@student.le.ac.uk      Html   Unknown
# ..        ...          ...                     ...       ...       ...
# 61          1            1  kl301@student.le.ac.uk      Html  Kaamilah
# 62          1            1   cxb1@student.le.ac.uk      Html   Unknown
# 63          1            1   hw349@leicester.ac.uk      Html   Unknown
# 64          1            1  ja533@student.le.ac.uk      Html   Unknown
# 65          1            1  adss1@student.le.ac.uk      Html   Unknown
#
#    Lastname
# 0   Unknown
# 1   Unknown
# 2    Karaer
# 3   Unknown
# 4   Unknown
# ..      ...
# 61  Unknown
# 62  Unknown
# 63  Unknown
# 64  Unknown
# 65  Unknown
#
# [66 rows x 6 columns]

# %%
df_clicksBHM23.head()
# Out:
#    NumClicks  NumClicks.1                   Email EmailType Firstname Lastname
# 0          1            1   ler20@leicester.ac.uk      Html   Loo Loo     Rose
# 1          1            1  jsaa2@student.le.ac.uk      Html       NaN      NaN
# 2          1            1  anr11@student.le.ac.uk      Html       NaN      NaN
# 3          1            1   dk266@leicester.ac.uk      Html     Didem   Karaer
# 4          1            1   batt1@leicester.ac.uk      Html       NaN      NaN

# %%
df_clicksBHM23.duplicated().sum()
# Out:
# 0

# %%
df_clicksBHM23.isnull().sum()
# Out:
# NumClicks       0
# NumClicks.1     0
# Email           0
# EmailType       0
# Firstname      58
# Lastname       59
# dtype: int64

# %%
df_clicksBHM23["Firstname"] = df_clicksBHM23["Firstname"].fillna("Unknown")
df_clicksBHM23["Lastname"] = df_clicksBHM23["Lastname"].fillna("Unknown")
df_clicksBHM23
# Out:
#     NumClicks  NumClicks.1                   Email EmailType Firstname  \
# 0           1            1   ler20@leicester.ac.uk      Html   Loo Loo
# 1           1            1  jsaa2@student.le.ac.uk      Html   Unknown
# 2           1            1  anr11@student.le.ac.uk      Html   Unknown
# 3           1            1   dk266@leicester.ac.uk      Html     Didem
# 4           1            1   batt1@leicester.ac.uk      Html   Unknown
# ..        ...          ...                     ...       ...       ...
# 59          1            1   joe3@student.le.ac.uk      Html   Unknown
# 60          1            1   pk310@leicester.ac.uk      Html   Unknown
# 61          1            1   cs856@leicester.ac.uk      Html   Unknown
# 62          1            1  mb933@student.le.ac.uk      Html   Unknown
# 63          1            1   jms99@leicester.ac.uk      Html      Judy
#
#    Lastname
# 0      Rose
# 1   Unknown
# 2   Unknown
# 3    Karaer
# 4   Unknown
# ..      ...
# 59  Unknown
# 60  Unknown
# 61  Unknown
# 62  Unknown
# 63   Somekh
#
# [64 rows x 6 columns]

# %%
df_clicksWellbeingday.head()
# Out:
#    NumClicks  NumClicks.1                   Email EmailType Firstname Lastname
# 0          1            1    ej86@leicester.ac.uk      Html       NaN      NaN
# 1          1            1   ay97@student.le.ac.uk      Html       NaN      NaN
# 2          1            1   iw73@student.le.ac.uk      Html       NaN      NaN
# 3          1            1  ztok1@student.le.ac.uk      Html       NaN      NaN
# 4          1            1    qj12@leicester.ac.uk      Html    Qishan    Jiang

# %%
df_clicksWellbeingday.duplicated().sum()
# Out:
# 0

# %%
df_clicksWellbeingday.isnull().sum()
# Out:
# NumClicks        0
# NumClicks.1      0
# Email            0
# EmailType        0
# Firstname      154
# Lastname       156
# dtype: int64

# %%
df_clicksWellbeingday["Firstname"] = df_clicksWellbeingday["Firstname"].fillna("Unknown")
df_clicksWellbeingday["Lastname"] = df_clicksWellbeingday["Lastname"].fillna("Unknown")
df_clicksWellbeingday
# Out:
#      NumClicks  NumClicks.1                   Email EmailType Firstname  \
# 0            1            1    ej86@leicester.ac.uk      Html   Unknown
# 1            1            1   ay97@student.le.ac.uk      Html   Unknown
# 2            1            1   iw73@student.le.ac.uk      Html   Unknown
# 3            1            1  ztok1@student.le.ac.uk      Html   Unknown
# 4            1            1    qj12@leicester.ac.uk      Html    Qishan
# ..         ...          ...                     ...       ...       ...
# 154          1            1  msa54@student.le.ac.uk      Html   Unknown
# 155          1            1  bc255@student.le.ac.uk      Html   Unknown
# 156          1            1  mi214@student.le.ac.uk      Html    Maryam
# 157          1            1   zhw2@student.le.ac.uk      Html   Unknown
# 158          1            1  dom10@student.le.ac.uk      Html   Unknown
#
#     Lastname
# 0    Unknown
# 1    Unknown
# 2    Unknown
# 3    Unknown
# 4      Jiang
# ..       ...
# 154  Unknown
# 155  Unknown
# 156  Unknown
# 157  Unknown
# 158  Unknown
#
# [159 rows x 6 columns]

# %%
df_recepient_clickslink.head()
# Out:
#                      Email  Html  \
# 0   pftw2@student.le.ac.uk  True
# 1   pftw2@student.le.ac.uk  True
# 2    ler20@leicester.ac.uk  True
# 3     ej86@leicester.ac.uk  True
# 4  sjw143@student.le.ac.uk  True
#
#                                                  Url       DateClicked  \
# 0    https://www.leicesterunion.com/ents/event/5004/  29/09/2023 09:53
# 1    https://www.leicesterunion.com/ents/event/5004/  29/09/2023 09:53
# 2        https://le.ac.uk/black-history-month/events  29/09/2023 09:55
# 3              https://le.ac.uk/study/welcome/events  29/09/2023 09:52
# 4  https://uniofleicester.sharepoint.com/sites/ne...  29/09/2023 10:28
#
#                                            UserAgent               IP  \
# 0  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   143.210.42.169
# 1  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   143.210.42.169
# 2  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...    2.103.101.198
# 3  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  143.210.187.105
# 4  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...    81.111.213.32
#
#          Keyword  LinkGroups
# 0        macrame         NaN
# 1        macrame         NaN
# 2          BHM23         NaN
# 3  Wellbeing day         NaN
# 4        support         NaN

# %%
df_recepient_clickslink.duplicated().sum()
# Out:
# 25

# %%
df_recepient_clickslink.drop_duplicates()
# Out:
#                        Email  Html  \
# 0     pftw2@student.le.ac.uk  True
# 2      ler20@leicester.ac.uk  True
# 3       ej86@leicester.ac.uk  True
# 4    sjw143@student.le.ac.uk  True
# 5     lac60@student.le.ac.uk  True
# ..                       ...   ...
# 588   adss1@student.le.ac.uk  True
# 589    jms99@leicester.ac.uk  True
# 590              vc@le.ac.uk  True
# 591     ehj3@leicester.ac.uk  True
# 592     lao9@leicester.ac.uk  True
#
#                                                    Url       DateClicked  \
# 0      https://www.leicesterunion.com/ents/event/5004/  29/09/2023 09:53
# 2          https://le.ac.uk/black-history-month/events  29/09/2023 09:55
# 3                https://le.ac.uk/study/welcome/events  29/09/2023 09:52
# 4    https://uniofleicester.sharepoint.com/sites/ne...  29/09/2023 10:28
# 5    https://uniofleicester.sharepoint.com/sites/st...  29/09/2023 10:31
# ..                                                 ...               ...
# 588                        https://le.ac.uk/autumnfest  29/09/2023 11:00
# 589        https://le.ac.uk/black-history-month/events  29/09/2023 12:32
# 590  https://uniofleicester.sharepoint.com/sites/ne...  29/09/2023 11:15
# 591              https://le.ac.uk/study/welcome/events  29/09/2023 10:54
# 592  https://uniofleicester.sharepoint.com/sites/ne...  29/09/2023 11:33
#
#                                              UserAgent               IP  \
# 0    Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   143.210.42.169
# 2    Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...    2.103.101.198
# 3    Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  143.210.187.105
# 4    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...    81.111.213.32
# 5    Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...   82.132.246.134
# ..                                                 ...              ...
# 588  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...    85.255.232.34
# 589  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   143.210.250.97
# 590  Mozilla/5.0 (iPhone; CPU iPhone OS 17_0_2 like...   143.210.250.96
# 591  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...    194.72.49.138
# 592  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...  195.213.199.169
#
#               Keyword  LinkGroups
# 0             macrame         NaN
# 2               BHM23         NaN
# 3       Wellbeing day         NaN
# 4             support         NaN
# 5     chatbot student         NaN
# ..                ...         ...
# 588        autunmfest         NaN
# 589             BHM23         NaN
# 590            coffee         NaN
# 591  Tea with provost         NaN
# 592            coffee         NaN
#
# [568 rows x 8 columns]

# %%
df_recepient_clickslink.isnull().sum()
# Out:
# Email            0
# Html             0
# Url              0
# DateClicked      0
# UserAgent        0
# IP               0
# Keyword         40
# LinkGroups     593
# dtype: int64

# %%
df_recepient_clickslink["Keyword"] = df_recepient_clickslink["Keyword"].fillna("Unknown")
df_recepient_clickslink["LinkGroups"] = df_recepient_clickslink["LinkGroups"].fillna("Unknown")
df_recepient_clickslink
# Out:
#                        Email  Html  \
# 0     pftw2@student.le.ac.uk  True
# 1     pftw2@student.le.ac.uk  True
# 2      ler20@leicester.ac.uk  True
# 3       ej86@leicester.ac.uk  True
# 4    sjw143@student.le.ac.uk  True
# ..                       ...   ...
# 588   adss1@student.le.ac.uk  True
# 589    jms99@leicester.ac.uk  True
# 590              vc@le.ac.uk  True
# 591     ehj3@leicester.ac.uk  True
# 592     lao9@leicester.ac.uk  True
#
#                                                    Url       DateClicked  \
# 0      https://www.leicesterunion.com/ents/event/5004/  29/09/2023 09:53
# 1      https://www.leicesterunion.com/ents/event/5004/  29/09/2023 09:53
# 2          https://le.ac.uk/black-history-month/events  29/09/2023 09:55
# 3                https://le.ac.uk/study/welcome/events  29/09/2023 09:52
# 4    https://uniofleicester.sharepoint.com/sites/ne...  29/09/2023 10:28
# ..                                                 ...               ...
# 588                        https://le.ac.uk/autumnfest  29/09/2023 11:00
# 589        https://le.ac.uk/black-history-month/events  29/09/2023 12:32
# 590  https://uniofleicester.sharepoint.com/sites/ne...  29/09/2023 11:15
# 591              https://le.ac.uk/study/welcome/events  29/09/2023 10:54
# 592  https://uniofleicester.sharepoint.com/sites/ne...  29/09/2023 11:33
#
#                                              UserAgent               IP  \
# 0    Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   143.210.42.169
# 1    Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   143.210.42.169
# 2    Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...    2.103.101.198
# 3    Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  143.210.187.105
# 4    Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...    81.111.213.32
# ..                                                 ...              ...
# 588  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...    85.255.232.34
# 589  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   143.210.250.97
# 590  Mozilla/5.0 (iPhone; CPU iPhone OS 17_0_2 like...   143.210.250.96
# 591  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...    194.72.49.138
# 592  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...  195.213.199.169
#
#               Keyword LinkGroups
# 0             macrame    Unknown
# 1             macrame    Unknown
# 2               BHM23    Unknown
# 3       Wellbeing day    Unknown
# 4             support    Unknown
# ..                ...        ...
# 588        autunmfest    Unknown
# 589             BHM23    Unknown
# 590            coffee    Unknown
# 591  Tea with provost    Unknown
# 592            coffee    Unknown
#
# [593 rows x 8 columns]

# %%
def total_opens():
    total_opens = df_emailopened["NumOpens"].sum()
    print("Total number of NumOpens: ", total_opens)



total_opens()
# Out:
# Total number of NumOpens:  25106

# %%
average_opens = df_emailopened["NumOpens"].mean()
df_emailopened["AverageNumOpens"] = average_opens

print("Average number of NumOpens:", average_opens)
# Out:
# Average number of NumOpens: 2.0528209321340967

# %%
minimum_opens = df_emailopened["NumOpens"].min()
df_emailopened["MinimumOpens"] = minimum_opens
print("Minimum number of NumOpens: ", minimum_opens)
# Out:
# Minimum number of NumOpens:  1

# %%
maximum_opens = df_emailopened["NumOpens"].max()
df_emailopened["MaximumOpens"] = maximum_opens
print("Maximum number of NumOpens: ", maximum_opens)
# Out:
# Maximum number of NumOpens:  34

# %%
df_emailopened["DateOpened"] = pd.to_datetime(df_emailopened["DateOpened"], format="%d/%m/%Y %H:%M") #convert string to datetime

# %%
df_emailopened["DateOpenedLast"] = pd.to_datetime(df_emailopened["DateOpenedLast"], format="%d/%m/%Y %H:%M") #convert string to datetime

# %%
df_emailopened["EngagementSpan"] = df_emailopened["DateOpenedLast"] - df_emailopened["DateOpened"]
df_emailopened.head(10)
# Out:
#    NumOpens                    Email EmailType          DateOpened  \
# 0         2    ucn1@student.le.ac.uk      Html 2023-10-02 16:35:00
# 1         2   jlpc1@student.le.ac.uk      Html 2023-10-15 18:06:00
# 2         1   jg562@student.le.ac.uk      Html 2023-10-25 17:08:00
# 3         1    vdg2@student.le.ac.uk      Html 2023-09-29 17:23:00
# 4         1   dcc26@student.le.ac.uk      Html 2023-09-29 13:33:00
# 5         1   arc39@student.le.ac.uk      Html 2023-11-08 17:31:00
# 6         2    zgp2@student.le.ac.uk      Html 2023-09-29 10:26:00
# 7         2   jarf1@student.le.ac.uk      Html 2023-09-29 10:22:00
# 8         1   cll46@student.le.ac.uk      Html 2023-09-29 16:39:00
# 9         3  ajp120@student.le.ac.uk      Html 2023-10-01 17:13:00
#
#        DateOpenedLast  AverageNumOpens  MinimumOpens  MaximumOpens  \
# 0 2023-10-02 16:35:00         2.052821             1            34
# 1 2023-10-15 18:06:00         2.052821             1            34
# 2 2023-10-25 17:08:00         2.052821             1            34
# 3 2023-09-29 17:23:00         2.052821             1            34
# 4 2023-09-29 13:33:00         2.052821             1            34
# 5 2023-11-08 17:31:00         2.052821             1            34
# 6 2023-09-29 10:26:00         2.052821             1            34
# 7 2023-09-29 10:22:00         2.052821             1            34
# 8 2023-09-29 16:39:00         2.052821             1            34
# 9 2023-10-08 18:22:00         2.052821             1            34
#
#    EngagementSpan
# 0 0 days 00:00:00
# 1 0 days 00:00:00
# 2 0 days 00:00:00
# 3 0 days 00:00:00
# 4 0 days 00:00:00
# 5 0 days 00:00:00
# 6 0 days 00:00:00
# 7 0 days 00:00:00
# 8 0 days 00:00:00
# 9 7 days 01:09:00

# %%
df_emailopened["EngagementHours"] = df_emailopened["EngagementSpan"].dt.total_seconds() / 3600
df_emailopened
# Out:
#        NumOpens                   Email EmailType          DateOpened  \
# 0             2   ucn1@student.le.ac.uk      Html 2023-10-02 16:35:00
# 1             2  jlpc1@student.le.ac.uk      Html 2023-10-15 18:06:00
# 2             1  jg562@student.le.ac.uk      Html 2023-10-25 17:08:00
# 3             1   vdg2@student.le.ac.uk      Html 2023-09-29 17:23:00
# 4             1  dcc26@student.le.ac.uk      Html 2023-09-29 13:33:00
# ...         ...                     ...       ...                 ...
# 12225         2   kh370@leicester.ac.uk      Html 2023-09-29 10:53:00
# 12226         1   ma880@leicester.ac.uk      Html 2023-09-29 11:14:00
# 12227         1   wiha1@leicester.ac.uk      Html 2023-09-29 11:15:00
# 12228         2         advice@le.ac.uk      Html 2023-09-29 11:01:00
# 12229         1     coursereps@le.ac.uk      Html 2023-09-29 12:02:00
#
#            DateOpenedLast  AverageNumOpens  MinimumOpens  MaximumOpens  \
# 0     2023-10-02 16:35:00         2.052821             1            34
# 1     2023-10-15 18:06:00         2.052821             1            34
# 2     2023-10-25 17:08:00         2.052821             1            34
# 3     2023-09-29 17:23:00         2.052821             1            34
# 4     2023-09-29 13:33:00         2.052821             1            34
# ...                   ...              ...           ...           ...
# 12225 2023-09-29 10:53:00         2.052821             1            34
# 12226 2023-09-29 11:14:00         2.052821             1            34
# 12227 2023-09-29 11:15:00         2.052821             1            34
# 12228 2023-09-29 11:01:00         2.052821             1            34
# 12229 2023-09-29 12:02:00         2.052821             1            34
#
#       EngagementSpan  EngagementHours
# 0             0 days              0.0
# 1             0 days              0.0
# 2             0 days              0.0
# 3             0 days              0.0
# 4             0 days              0.0
# ...              ...              ...
# 12225         0 days              0.0
# 12226         0 days              0.0
# 12227         0 days              0.0
# 12228         0 days              0.0
# 12229         0 days              0.0
#
# [12230 rows x 10 columns]

# %%
def numopen_level_classification(opens): #categorising open levels into different categories
    if opens <= 1:
        return 'Low'
    elif opens <= 4:
        return 'Medium'
    else:
        return 'High'

# %%
df_emailopened["Openlevel"] = df_emailopened["NumOpens"].apply(numopen_level_classification)
df_emailopened
# Out:
#        NumOpens                   Email EmailType          DateOpened  \
# 0             2   ucn1@student.le.ac.uk      Html 2023-10-02 16:35:00
# 1             2  jlpc1@student.le.ac.uk      Html 2023-10-15 18:06:00
# 2             1  jg562@student.le.ac.uk      Html 2023-10-25 17:08:00
# 3             1   vdg2@student.le.ac.uk      Html 2023-09-29 17:23:00
# 4             1  dcc26@student.le.ac.uk      Html 2023-09-29 13:33:00
# ...         ...                     ...       ...                 ...
# 12225         2   kh370@leicester.ac.uk      Html 2023-09-29 10:53:00
# 12226         1   ma880@leicester.ac.uk      Html 2023-09-29 11:14:00
# 12227         1   wiha1@leicester.ac.uk      Html 2023-09-29 11:15:00
# 12228         2         advice@le.ac.uk      Html 2023-09-29 11:01:00
# 12229         1     coursereps@le.ac.uk      Html 2023-09-29 12:02:00
#
#            DateOpenedLast  AverageNumOpens  MinimumOpens  MaximumOpens  \
# 0     2023-10-02 16:35:00         2.052821             1            34
# 1     2023-10-15 18:06:00         2.052821             1            34
# 2     2023-10-25 17:08:00         2.052821             1            34
# 3     2023-09-29 17:23:00         2.052821             1            34
# 4     2023-09-29 13:33:00         2.052821             1            34
# ...                   ...              ...           ...           ...
# 12225 2023-09-29 10:53:00         2.052821             1            34
# 12226 2023-09-29 11:14:00         2.052821             1            34
# 12227 2023-09-29 11:15:00         2.052821             1            34
# 12228 2023-09-29 11:01:00         2.052821             1            34
# 12229 2023-09-29 12:02:00         2.052821             1            34
#
#       EngagementSpan  EngagementHours Openlevel
# 0             0 days              0.0    Medium
# 1             0 days              0.0    Medium
# 2             0 days              0.0       Low
# 3             0 days              0.0       Low
# 4             0 days              0.0       Low
# ...              ...              ...       ...
# 12225         0 days              0.0    Medium
# 12226         0 days              0.0       Low
# 12227         0 days              0.0       Low
# 12228         0 days              0.0    Medium
# 12229         0 days              0.0       Low
#
# [12230 rows x 11 columns]

# %%
df_emailopened["Openlevel"].value_counts().plot(kind='bar', title='Email Engagement Levels')
plt.ylabel("Number of People")
plt.show()
df_emailopened["Openlevel"].value_counts()
#high levels of medium open level
#low levels of high open level
# Out:
# Medium    7076
# Low       4558
# High       596
# Name: Openlevel, dtype: int64

# %%
df_emailopened.groupby("EmailType")["AverageNumOpens"].mean().plot(kind="bar", title="Average Opens per Email Type")
plt.ylabel("Average Opens")
plt.show()
df_emailopened.groupby("EmailType")["AverageNumOpens"].value_counts()
# Out:
# EmailType  AverageNumOpens
# Html       2.052821           12230
# Name: AverageNumOpens, dtype: int64

# %%
bins = pd.cut(df_emailopened['EngagementHours'], bins=10).value_counts().sort_index()
print(bins)

df_emailopened['EngagementHours'].plot(kind='hist', bins=10, title='Distribution of Engagement Hours')
plt.show()
# Out:
# (-15.123, 1512.3]     12039
# (1512.3, 3024.6]         71
# (3024.6, 4536.9]         45
# (4536.9, 6049.2]         23
# (6049.2, 7561.5]         20
# (7561.5, 9073.8]         12
# (9073.8, 10586.1]         6
# (10586.1, 12098.4]        9
# (12098.4, 13610.7]        3
# (13610.7, 15123.0]        2
# Name: EngagementHours, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(
    x='Openlevel',
    y='EngagementHours',
    data=df_emailopened,
    boxprops=dict(facecolor='white', edgecolor='black'),
    whiskerprops=dict(color='black'),
    capprops=dict(color='black'),
    medianprops=dict(color='black'),
    flierprops=dict(marker='o', color='black', alpha=0.3, markersize=3),
    showfliers=True
)

plt.yscale('log')  #log scale to handle skewed data
plt.title('Engagement Span by Open Level (Log Scale)')
plt.grid(True, which="both", axis='y', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()

sns.boxplot(x='Openlevel', y='EngagementHours', data=df_emailopened).set_title('Engagement Span by Open Level')


df_emailopened.groupby("Openlevel")["EngagementHours"].std()
# Out:
# Openlevel
# High      1422.112064
# Low          0.000000
# Medium     825.602478
# Name: EngagementHours, dtype: float64

# %%
##most and least clicked links

def total_clicks():
    total_clicksautumnfest = df_clicksautumnfest["NumClicks"].sum()
    print("Total number of NumClicks for https://le.ac.uk/autumnfest: ", total_clicksautumnfest)
    
    total_clicksBHM23 = df_clicksBHM23["NumClicks"].sum()
    print("Total number of NumClicks for https://le.ac.uk/black-history-month/events: ", total_clicksBHM23)
    

    total_clicksWellbeingday = df_clicksWellbeingday["NumClicks"].sum()
    print("Total number of NumClicks for https://le.ac.uk/study/welcome/events: ", total_clicksWellbeingday)
    

 
    
    
total_clicks()
# Out:
# Total number of NumClicks for https://le.ac.uk/autumnfest:  75
# Total number of NumClicks for https://le.ac.uk/black-history-month/events:  73
# Total number of NumClicks for https://le.ac.uk/study/welcome/events:  203
