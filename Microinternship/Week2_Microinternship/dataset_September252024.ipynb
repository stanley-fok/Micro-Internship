# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from datetime import datetime

# %%
df_emailopened = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September252024/The-Citizen-What-s-on-Wednesday-25-September-2024-EmailOpened.csv")

df_emailsends = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September252024/The-Citizen-What-s-on-Wednesday-25-September-2024-EmailSends.csv")

df_clicksMatriculationSurvey = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September252024/The-Citizen-What-s-on-Wednesday-25-September-2024-Link-clicksMatriculation Survey.csv")

df_clicksMiniplantpotdecorating = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September252024/The-Citizen-What-s-on-Wednesday-25-September-2024-Link-clicksMini plant pot decorating.csv")

df_clicksMurderMysterynight = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September252024/The-Citizen-What-s-on-Wednesday-25-September-2024-Link-clicksMurder Mystery night.csv")

df_recepient_clickslink = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September252024/The-Citizen-What-s-on-Wednesday-25-September-2024-Recipient-clickslink.csv")

# %%
df_emailopened.head()
# Out:
#    NumOpens                   Email EmailType        DateOpened  \
# 0         1   ucn1@student.le.ac.uk      Html  25/09/2024 11:34
# 1         2   vdg2@student.le.ac.uk      Html  25/09/2024 21:28
# 2         1  dcc26@student.le.ac.uk      Html  26/09/2024 02:20
# 3         2  hc365@student.le.ac.uk      Html  25/09/2024 12:08
# 4         2   wlr1@student.le.ac.uk      Html  30/09/2024 16:36
#
#      DateOpenedLast
# 0  25/09/2024 11:34
# 1  26/09/2024 08:38
# 2  26/09/2024 02:20
# 3  01/10/2024 07:34
# 4  30/09/2024 16:36

# %%
df_emailsends.value_counts()
# Out:
# Email                    DateSent          Firstname        Lastname          EmailType
# aa1034@leicester.ac.uk   25/09/2024 10:33  Ahmad            Abouelnour        Html         1
# ndj11@leicester.ac.uk    25/09/2024 10:33  Nicholas         Janicki           Html         1
# ms1165@leicester.ac.uk   25/09/2024 10:33  Mariella         Scerri            Html         1
# ms1246@student.le.ac.uk  25/09/2024 10:33  Melody           Saya              Html         1
# msa52@student.le.ac.uk   25/09/2024 10:33  Megan            STAFFORD-ADATIA   Html         1
#                                                                                           ..
# gip2@leicester.ac.uk     25/09/2024 10:33  Georgia          Parsisson         Html         1
# gk214@student.le.ac.uk   25/09/2024 10:33  Grace Susannah   KLEMPERER         Html         1
# gm239@leicester.ac.uk    25/09/2024 10:33  Luca             Moliterni         Html         1
# ...

# %%
df_emailopened.duplicated().sum()
# Out:
# 0

# %%
df_emailopened.isnull().sum()
# Out:
# NumOpens          0
# Email             0
# EmailType         0
# DateOpened        0
# DateOpenedLast    0
# dtype: int64

# %%
df_emailsends.head()
# Out:
#                     Email          DateSent Firstname Lastname EmailType
# 0   ucn1@student.le.ac.uk  25/09/2024 10:33       NaN      NaN      Html
# 1  jlpc1@student.le.ac.uk  25/09/2024 10:33       NaN      NaN      Html
# 2  jg562@student.le.ac.uk  25/09/2024 10:33       NaN      NaN      Html
# 3   vdg2@student.le.ac.uk  25/09/2024 10:33       NaN      NaN      Html
# 4  dcc26@student.le.ac.uk  25/09/2024 10:33       NaN      NaN      Html

# %%
df_emailsends.duplicated().sum()
# Out:
# 0

# %%
df_emailsends.isnull().sum()
# Out:
# Email            0
# DateSent         0
# Firstname    25633
# Lastname     25712
# EmailType        0
# dtype: int64

# %%
df_emailsends['Firstname'] = df_emailsends['Firstname'].fillna('Unknown')
df_emailsends['Lastname'] = df_emailsends['Lastname'].fillna('Unknown')
df_emailsends
# Out:
#                         Email          DateSent Firstname  Lastname EmailType
# 0       ucn1@student.le.ac.uk  25/09/2024 10:33   Unknown   Unknown      Html
# 1      jlpc1@student.le.ac.uk  25/09/2024 10:33   Unknown   Unknown      Html
# 2      jg562@student.le.ac.uk  25/09/2024 10:33   Unknown   Unknown      Html
# 3       vdg2@student.le.ac.uk  25/09/2024 10:33   Unknown   Unknown      Html
# 4      dcc26@student.le.ac.uk  25/09/2024 10:33   Unknown   Unknown      Html
# ...                       ...               ...       ...       ...       ...
# 26362  cwm18@student.le.ac.uk  25/09/2024 10:33   Unknown   Unknown      Html
# 26363   zo17@student.le.ac.uk  25/09/2024 10:33   Unknown   Unknown      Html
# 26364   fama4@leicester.ac.uk  25/09/2024 10:33   Fatimah  Alsaiari      Html
# 26365   kh370@leicester.ac.uk  25/09/2024 10:33  Karianne    Hansen      Html
# 26366     coursereps@le.ac.uk  25/09/2024 10:33   Unknown   Unknown      Html
#
# [26367 rows x 5 columns]

# %%
df_clicksMatriculationSurvey.head()
# Out:
#    NumClicks  NumClicks.1                   Email EmailType  Firstname  \
# 0          2            2  tn103@student.le.ac.uk      Html        NaN
# 1          1            1  ma887@student.le.ac.uk      Html        NaN
# 2          1            1   on32@student.le.ac.uk      Html        NaN
# 3          1            1  tas35@student.le.ac.uk      Html        NaN
# 4          1            1  mb961@student.le.ac.uk      Html        NaN
#
#    Lastname
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
df_clicksMatriculationSurvey.duplicated().sum()
# Out:
# 0

# %%
df_clicksMatriculationSurvey.isnull().sum()
# Out:
# NumClicks       0
# NumClicks.1     0
# Email           0
# EmailType       0
# Firstname      98
# Lastname       98
# dtype: int64

# %%
df_clicksMatriculationSurvey['Firstname'] = df_clicksMatriculationSurvey['Firstname'].fillna('Unknown')
df_clicksMatriculationSurvey['Lastname'] = df_clicksMatriculationSurvey['Lastname'].fillna('Unknown')
df_clicksMatriculationSurvey
# Out:
#     NumClicks  NumClicks.1                    Email EmailType Firstname  \
# 0           2            2   tn103@student.le.ac.uk      Html   Unknown
# 1           1            1   ma887@student.le.ac.uk      Html   Unknown
# 2           1            1    on32@student.le.ac.uk      Html   Unknown
# 3           1            1   tas35@student.le.ac.uk      Html   Unknown
# 4           1            1   mb961@student.le.ac.uk      Html   Unknown
# ..        ...          ...                      ...       ...       ...
# 93          1            1   gjw26@student.le.ac.uk      Html   Unknown
# 94          1            1    jmla3@leicester.ac.uk      Html   Unknown
# 95          1            1   jb924@student.le.ac.uk      Html   Unknown
# 96          1            1  am1361@student.le.ac.uk      Html   Unknown
# 97          1            1   dom10@student.le.ac.uk      Html   Unknown
#
#    Lastname
# 0   Unknown
# 1   Unknown
# 2   Unknown
# 3   Unknown
# 4   Unknown
# ..      ...
# ...

# %%
df_clicksMiniplantpotdecorating.head()
# Out:
#    NumClicks  NumClicks.1                   Email EmailType Firstname  \
# 0          1            1  nw176@student.le.ac.uk      Html       NaN
# 1          1            1   ran14@leicester.ac.uk      Html       NaN
# 2          1            1  cl477@student.le.ac.uk      Html       NaN
# 3          1            1   krq1@student.le.ac.uk      Html       NaN
# 4          1            1    gig2@leicester.ac.uk      Html       NaN
#
#    Lastname
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
df_clicksMiniplantpotdecorating.duplicated().sum()
# Out:
# 0

# %%
df_clicksMiniplantpotdecorating.isnull().sum()
# Out:
# NumClicks        0
# NumClicks.1      0
# Email            0
# EmailType        0
# Firstname      165
# Lastname       167
# dtype: int64

# %%
df_clicksMiniplantpotdecorating['Firstname'] = df_clicksMiniplantpotdecorating['Firstname'].fillna('Unknown')
df_clicksMiniplantpotdecorating['Lastname'] = df_clicksMiniplantpotdecorating['Lastname'].fillna('Unknown')
df_clicksMiniplantpotdecorating
# Out:
#      NumClicks  NumClicks.1                   Email EmailType Firstname  \
# 0            1            1  nw176@student.le.ac.uk      Html   Unknown
# 1            1            1   ran14@leicester.ac.uk      Html   Unknown
# 2            1            1  cl477@student.le.ac.uk      Html   Unknown
# 3            1            1   krq1@student.le.ac.uk      Html   Unknown
# 4            1            1    gig2@leicester.ac.uk      Html   Unknown
# ..         ...          ...                     ...       ...       ...
# 162          1            1   cs856@leicester.ac.uk      Html   Unknown
# 163          1            1   li32@student.le.ac.uk      Html   Unknown
# 164          1            1  km572@student.le.ac.uk      Html   Unknown
# 165          1            1  am1412@leicester.ac.uk      Html   Unknown
# 166          1            1   vmss2@leicester.ac.uk      Html   Unknown
#
#     Lastname
# 0    Unknown
# 1    Unknown
# 2    Unknown
# 3    Unknown
# 4    Unknown
# ..       ...
# ...

# %%
df_clicksMurderMysterynight.head()
# Out:
#    NumClicks  NumClicks.1                   Email EmailType  Firstname  \
# 0          1            1   ran14@leicester.ac.uk      Html        NaN
# 1          1            1   elg29@leicester.ac.uk      Html        NaN
# 2          1            1  za113@student.le.ac.uk      Html        NaN
# 3          1            1   bs374@leicester.ac.uk      Html        NaN
# 4          1            1   bjm35@leicester.ac.uk      Html        NaN
#
#    Lastname
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
df_clicksMurderMysterynight.duplicated().sum()
# Out:
# 0

# %%
df_clicksMurderMysterynight.isnull().sum()
# Out:
# NumClicks       0
# NumClicks.1     0
# Email           0
# EmailType       0
# Firstname      99
# Lastname       99
# dtype: int64

# %%
df_clicksMurderMysterynight['Firstname'] = df_clicksMurderMysterynight['Firstname'].fillna('Unknown')
df_clicksMurderMysterynight['Lastname'] = df_clicksMurderMysterynight['Lastname'].fillna('Unknown')
df_clicksMurderMysterynight
# Out:
#     NumClicks  NumClicks.1                    Email EmailType Firstname  \
# 0           1            1    ran14@leicester.ac.uk      Html   Unknown
# 1           1            1    elg29@leicester.ac.uk      Html   Unknown
# 2           1            1   za113@student.le.ac.uk      Html   Unknown
# 3           1            1    bs374@leicester.ac.uk      Html   Unknown
# 4           1            1    bjm35@leicester.ac.uk      Html   Unknown
# ..        ...          ...                      ...       ...       ...
# 94          1            1  sb1037@student.le.ac.uk      Html   Unknown
# 95          1            1   ia255@student.le.ac.uk      Html   Unknown
# 96          1            1    elw41@leicester.ac.uk      Html   Unknown
# 97          3            3    ardf1@leicester.ac.uk      Html   Unknown
# 98          1            1   am1412@leicester.ac.uk      Html   Unknown
#
#    Lastname
# 0   Unknown
# 1   Unknown
# 2   Unknown
# 3   Unknown
# 4   Unknown
# ..      ...
# ...

# %%
df_recepient_clickslink.head()
# Out:
#                     Email  Html  \
# 0   rds30@leicester.ac.uk  True
# 1   rds30@leicester.ac.uk  True
# 2  mama28@leicester.ac.uk  True
# 3  mama28@leicester.ac.uk  True
# 4   lh389@leicester.ac.uk  True
#
#                                                  Url       DateClicked  \
# 0           https://www.instagram.com/p/C7G3yGYNeDj/  30/09/2024 10:12
# 1           https://www.instagram.com/p/C7G3yGYNeDj/  30/09/2024 10:08
# 2  https://www.tickettailor.com/events/uolinterna...  25/09/2024 11:38
# 3           https://www.instagram.com/p/C7G3yGYNeDj/  25/09/2024 11:37
# 4           https://www.instagram.com/p/C7G3yGYNeDj/  25/09/2024 10:34
#
#                                            UserAgent               IP  \
# 0  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...    81.107.88.126
# 1  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...    81.107.88.126
# 2  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   143.210.250.98
# ...

# %%
df_recepient_clickslink.duplicated().sum()
# Out:
# 12

# %%
df_recepient_clickslink.drop_duplicates()
# Out:
#                        Email  Html  \
# 0      rds30@leicester.ac.uk  True
# 1      rds30@leicester.ac.uk  True
# 2     mama28@leicester.ac.uk  True
# 3     mama28@leicester.ac.uk  True
# 4      lh389@leicester.ac.uk  True
# ...                      ...   ...
# 1038   crj11@leicester.ac.uk  True
# 1039   jdb18@leicester.ac.uk  True
# 1040   sw509@leicester.ac.uk  True
# 1041   sw509@leicester.ac.uk  True
# 1042   sw509@leicester.ac.uk  True
#
#                                                     Url       DateClicked  \
# 0              https://www.instagram.com/p/C7G3yGYNeDj/  30/09/2024 10:12
# 1              https://www.instagram.com/p/C7G3yGYNeDj/  30/09/2024 10:08
# 2     https://www.tickettailor.com/events/uolinterna...  25/09/2024 11:38
# 3              https://www.instagram.com/p/C7G3yGYNeDj/  25/09/2024 11:37
# 4              https://www.instagram.com/p/C7G3yGYNeDj/  25/09/2024 10:34
# ...                                                 ...               ...
# ...

# %%
df_recepient_clickslink.isnull().sum()
# Out:
# Email           0
# Html            0
# Url             0
# DateClicked     0
# UserAgent       0
# IP              0
# Keyword        68
# LinkGroups     68
# dtype: int64

# %%
df_recepient_clickslink["Keyword"] = df_recepient_clickslink["Keyword"].fillna("Unknown")
df_recepient_clickslink["LinkGroups"] = df_recepient_clickslink["LinkGroups"].fillna("Unknown")
df_recepient_clickslink
# Out:
#                        Email  Html  \
# 0      rds30@leicester.ac.uk  True
# 1      rds30@leicester.ac.uk  True
# 2     mama28@leicester.ac.uk  True
# 3     mama28@leicester.ac.uk  True
# 4      lh389@leicester.ac.uk  True
# ...                      ...   ...
# 1038   crj11@leicester.ac.uk  True
# 1039   jdb18@leicester.ac.uk  True
# 1040   sw509@leicester.ac.uk  True
# 1041   sw509@leicester.ac.uk  True
# 1042   sw509@leicester.ac.uk  True
#
#                                                     Url       DateClicked  \
# 0              https://www.instagram.com/p/C7G3yGYNeDj/  30/09/2024 10:12
# 1              https://www.instagram.com/p/C7G3yGYNeDj/  30/09/2024 10:08
# 2     https://www.tickettailor.com/events/uolinterna...  25/09/2024 11:38
# 3              https://www.instagram.com/p/C7G3yGYNeDj/  25/09/2024 11:37
# 4              https://www.instagram.com/p/C7G3yGYNeDj/  25/09/2024 10:34
# ...                                                 ...               ...
# ...

# %%
def total_opens():
    total_opens = df_emailopened["NumOpens"].sum()
    print("Total number of NumOpens: ", total_opens)



total_opens()
# Out:
# Total number of NumOpens:  23430

# %%
average_opens = df_emailopened["NumOpens"].mean()
df_emailopened["AverageNumOpens"] = average_opens

print("Average number of NumOpens:", average_opens)
# Out:
# Average number of NumOpens: 1.9466600199401796

# %%
minimum_opens = df_emailopened["NumOpens"].min()
df_emailopened["MinimumOpens"] = minimum_opens
print("Minimum number of NumOpens: ", minimum_opens)
# Out:
# Minimum number of NumOpens:  1

# %%
maximum_opens = df_emailopened["NumOpens"].max()
print("Maximum number of NumOpens: ", maximum_opens)
# Out:
# Maximum number of NumOpens:  14

# %%
df_emailopened["DateOpened"] = pd.to_datetime(df_emailopened["DateOpened"], format="%d/%m/%Y %H:%M") #convert string to datetime

# %%
df_emailopened["DateOpenedLast"] = pd.to_datetime(df_emailopened["DateOpenedLast"], format="%d/%m/%Y %H:%M") #convert string to datetime

# %%
df_emailopened["EngagementSpan"] = df_emailopened["DateOpenedLast"] - df_emailopened["DateOpened"]
df_emailopened.head(10)
# Out:
#    NumOpens                    Email EmailType          DateOpened  \
# 0         1    ucn1@student.le.ac.uk      Html 2024-09-25 11:34:00
# 1         2    vdg2@student.le.ac.uk      Html 2024-09-25 21:28:00
# 2         1   dcc26@student.le.ac.uk      Html 2024-09-26 02:20:00
# 3         2   hc365@student.le.ac.uk      Html 2024-09-25 12:08:00
# 4         2    wlr1@student.le.ac.uk      Html 2024-09-30 16:36:00
# 5         1   shia1@student.le.ac.uk      Html 2024-09-25 11:17:00
# 6         1   cll46@student.le.ac.uk      Html 2024-09-25 11:02:00
# 7         1  ajp120@student.le.ac.uk      Html 2024-09-26 19:06:00
# 8         2    ahaa8@leicester.ac.uk      Html 2024-09-25 20:55:00
# 9         2    rs802@leicester.ac.uk      Html 2024-09-25 10:41:00
#
#        DateOpenedLast  AverageNumOpens  MinimumOpens  EngagementSpan
# 0 2024-09-25 11:34:00          1.94666             1 0 days 00:00:00
# 1 2024-09-26 08:38:00          1.94666             1 0 days 11:10:00
# ...

# %%
df_emailopened["EngagementHours"] = df_emailopened["EngagementSpan"].dt.total_seconds() / 3600
df_emailopened
# Out:
#        NumOpens                     Email EmailType          DateOpened  \
# 0             1     ucn1@student.le.ac.uk      Html 2024-09-25 11:34:00
# 1             2     vdg2@student.le.ac.uk      Html 2024-09-25 21:28:00
# 2             1    dcc26@student.le.ac.uk      Html 2024-09-26 02:20:00
# 3             2    hc365@student.le.ac.uk      Html 2024-09-25 12:08:00
# 4             2     wlr1@student.le.ac.uk      Html 2024-09-30 16:36:00
# ...         ...                       ...       ...                 ...
# 12031         1     lw322@leicester.ac.uk      Html 2024-09-25 14:05:00
# 12032         2  amy.cory@leicester.ac.uk      Html 2024-09-25 12:13:00
# 12033         3    cwm18@student.le.ac.uk      Html 2025-05-29 10:47:00
# 12034         1     fama4@leicester.ac.uk      Html 2024-09-25 11:08:00
# 12035         1       coursereps@le.ac.uk      Html 2024-09-25 10:37:00
#
#            DateOpenedLast  AverageNumOpens  MinimumOpens  EngagementSpan  \
# ...

# %%
def numopen_level_classification(opens): #categorising open levels into different categories
    if opens <= 1:
        return 'Low'
    elif opens <= 4:
        return 'Medium'
    else:
        return 'High'

# %%
df_emailopened["Openlevel"] = df_emailopened["NumOpens"].apply(numopen_level_classification)
df_emailopened
# Out:
#        NumOpens                     Email EmailType          DateOpened  \
# 0             1     ucn1@student.le.ac.uk      Html 2024-09-25 11:34:00
# 1             2     vdg2@student.le.ac.uk      Html 2024-09-25 21:28:00
# 2             1    dcc26@student.le.ac.uk      Html 2024-09-26 02:20:00
# 3             2    hc365@student.le.ac.uk      Html 2024-09-25 12:08:00
# 4             2     wlr1@student.le.ac.uk      Html 2024-09-30 16:36:00
# ...         ...                       ...       ...                 ...
# 12031         1     lw322@leicester.ac.uk      Html 2024-09-25 14:05:00
# 12032         2  amy.cory@leicester.ac.uk      Html 2024-09-25 12:13:00
# 12033         3    cwm18@student.le.ac.uk      Html 2025-05-29 10:47:00
# 12034         1     fama4@leicester.ac.uk      Html 2024-09-25 11:08:00
# 12035         1       coursereps@le.ac.uk      Html 2024-09-25 10:37:00
#
#            DateOpenedLast  AverageNumOpens  MinimumOpens  EngagementSpan  \
# ...

# %%
df_emailopened["Openlevel"].value_counts().plot(kind='bar', title='Email Engagement Levels')
plt.ylabel("Number of People")
plt.show()
df_emailopened["Openlevel"].value_counts()
#high levels of medium open level
#low levels of high open level
# Out:
# Medium    7217
# Low       4426
# High       393
# Name: Openlevel, dtype: int64

# %%
df_emailopened.groupby("EmailType")["AverageNumOpens"].mean().plot(kind="bar", title="Average Opens per Email Type")
plt.ylabel("Average Opens")
plt.show()
df_emailopened.groupby("EmailType")["AverageNumOpens"].value_counts()
# Out:
# EmailType  AverageNumOpens
# Html       1.94666            12036
# Name: AverageNumOpens, dtype: int64

# %%
# Bin the data into 10 bins using pd.cut
bins = pd.cut(df_emailopened['EngagementHours'], bins=10).value_counts().sort_index()
print(bins)

df_emailopened['EngagementHours'].plot(kind='hist', bins=10, title='Distribution of Engagement Hours')
plt.show()

#timeframe of engagement hours (timeframe email is opened), frequency == amount of people
# Out:
# (-6.602, 660.162]       11771
# (660.162, 1320.323]        98
# (1320.323, 1980.485]       35
# (1980.485, 2640.647]       22
# (2640.647, 3300.808]       37
# (3300.808, 3960.97]        24
# (3960.97, 4621.132]        17
# (4621.132, 5281.293]       13
# (5281.293, 5941.455]       13
# (5941.455, 6601.617]        6
# Name: EngagementHours, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(
    x='Openlevel',
    y='EngagementHours',
    data=df_emailopened,
    boxprops=dict(facecolor='white', edgecolor='black'),
    whiskerprops=dict(color='black'),
    capprops=dict(color='black'),
    medianprops=dict(color='black'),
    flierprops=dict(marker='o', color='black', alpha=0.3, markersize=3),
    showfliers=True
)

plt.yscale('log')  #log scale to handle skewed data
plt.title('Engagement Span by Open Level (Log Scale)')
plt.grid(True, which="both", axis='y', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()


sns.boxplot(x='Openlevel', y='EngagementHours', data=df_emailopened).set_title('Engagement Span by Open Level')

df_emailopened.groupby("Openlevel")["EngagementHours"].std()
# Out:
# Openlevel
# High      955.581142
# Low         0.000000
# Medium    495.686751
# Name: EngagementHours, dtype: float64

# %%
##most and least clicked links

def total_clicks():
    total_clicksMatriculationSurvey = df_clicksMatriculationSurvey["NumClicks"].sum()
    print("Total number of NumClicks for https://r1-app.dotdigital.com/analytics/reports/emailcampaigns/linkclicks/14669327?l=337061476 : ", total_clicksMatriculationSurvey)
    
    total_clicksMiniplantpotdecorating = df_clicksMiniplantpotdecorating["NumClicks"].sum()
    print("Total number of NumClicks for https://le.ac.uk/study/welcome/events : ", total_clicksMiniplantpotdecorating)
    

    total_clicksMurderMysterynight = df_clicksMurderMysterynight["NumClicks"].sum()
    print("Total number of NumClicks for https://im-puzzled.com/ : ",  total_clicksMurderMysterynight)
    
    
    
    
    



total_clicks()
# Out:
# Total number of NumClicks for https://r1-app.dotdigital.com/analytics/reports/emailcampaigns/linkclicks/14669327?l=337061476 :  118
# Total number of NumClicks for https://le.ac.uk/study/welcome/events :  202
# Total number of NumClicks for https://im-puzzled.com/ :  123
