# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from datetime import datetime

# %%
df_emailopened = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September232024/The-Citizen-What-s-on-Monday-23-September-2024-️EmailOpened.csv")

df_emailsends = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September232024/The-Citizen-What-s-on-Monday-23-September-2024-️EmailSends.csv")

df_clicksmatriculation = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September232024/The-Citizen-What-s-on-Monday-23-September-2024-️Link-clicks️Matriculation.csv")

df_clicksSUCarnival = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September232024/The-Citizen-What-s-on-Monday-23-September-2024-Link-clicksSU Carnival.csv")

df_clicksVintagesale = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September232024/The-Citizen-What-s-on-Monday-23-September-2024-️Link-clicksVintage sale.csv")

df_recepient_clickslink = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September232024/The-Citizen-What-s-on-Monday-23-September-2024-Recipient-clickslink.csv")

# %%
df_emailopened.head()
# Out:
#    NumOpens                   Email EmailType        DateOpened  \
# 0         2   ucn1@student.le.ac.uk      Html  23/09/2024 10:42
# 1         2   vdg2@student.le.ac.uk      Html  24/09/2024 01:03
# 2         1  dcc26@student.le.ac.uk      Html  26/09/2024 02:20
# 3         2  hc365@student.le.ac.uk      Html  23/09/2024 11:21
# 4         1   wlr1@student.le.ac.uk      Html  23/09/2024 13:38
#
#      DateOpenedLast
# 0  23/09/2024 10:42
# 1  25/09/2024 21:27
# 2  26/09/2024 02:20
# 3  11/10/2024 12:25
# 4  23/09/2024 13:38

# %%
df_emailsends.value_counts()
# Out:
# Email                    DateSent          Firstname        Lastname          EmailType
# aa1034@leicester.ac.uk   23/09/2024 10:29  Ahmad            Abouelnour        Html         1
# ndj11@leicester.ac.uk    23/09/2024 10:29  Nicholas         Janicki           Html         1
# ms1165@leicester.ac.uk   23/09/2024 10:29  Mariella         Scerri            Html         1
# ms1246@student.le.ac.uk  23/09/2024 10:29  Melody           Saya              Html         1
# msa52@student.le.ac.uk   23/09/2024 10:29  Megan            STAFFORD-ADATIA   Html         1
#                                                                                           ..
# gip2@leicester.ac.uk     23/09/2024 10:29  Georgia          Parsisson         Html         1
# gk214@student.le.ac.uk   23/09/2024 10:29  Grace Susannah   KLEMPERER         Html         1
# gm239@leicester.ac.uk    23/09/2024 10:29  Luca             Moliterni         Html         1
# ...

# %%
df_emailopened.duplicated().sum()
# Out:
# 0

# %%
df_emailopened.isnull().sum()
# Out:
# NumOpens          0
# Email             0
# EmailType         0
# DateOpened        0
# DateOpenedLast    0
# dtype: int64

# %%
df_emailsends.head()
# Out:
#                     Email          DateSent Firstname Lastname EmailType
# 0   ucn1@student.le.ac.uk  23/09/2024 10:29       NaN      NaN      Html
# 1  jlpc1@student.le.ac.uk  23/09/2024 10:29       NaN      NaN      Html
# 2  jg562@student.le.ac.uk  23/09/2024 10:29       NaN      NaN      Html
# 3   vdg2@student.le.ac.uk  23/09/2024 10:29       NaN      NaN      Html
# 4  dcc26@student.le.ac.uk  23/09/2024 10:29       NaN      NaN      Html

# %%
df_emailsends.duplicated().sum()
# Out:
# 0

# %%
df_emailsends.isnull().sum()
# Out:
# Email            0
# DateSent         0
# Firstname    25395
# Lastname     25474
# EmailType        0
# dtype: int64

# %%
df_emailsends['Firstname'] = df_emailsends['Firstname'].fillna('Unknown')
df_emailsends['Lastname'] = df_emailsends['Lastname'].fillna('Unknown')
df_emailsends
# Out:
#                         Email          DateSent Firstname  Lastname EmailType
# 0       ucn1@student.le.ac.uk  23/09/2024 10:29   Unknown   Unknown      Html
# 1      jlpc1@student.le.ac.uk  23/09/2024 10:29   Unknown   Unknown      Html
# 2      jg562@student.le.ac.uk  23/09/2024 10:29   Unknown   Unknown      Html
# 3       vdg2@student.le.ac.uk  23/09/2024 10:29   Unknown   Unknown      Html
# 4      dcc26@student.le.ac.uk  23/09/2024 10:29   Unknown   Unknown      Html
# ...                       ...               ...       ...       ...       ...
# 26124  cwm18@student.le.ac.uk  23/09/2024 10:29   Unknown   Unknown      Html
# 26125   zo17@student.le.ac.uk  23/09/2024 10:29   Unknown   Unknown      Html
# 26126   fama4@leicester.ac.uk  23/09/2024 10:29   Fatimah  Alsaiari      Html
# 26127   kh370@leicester.ac.uk  23/09/2024 10:29  Karianne    Hansen      Html
# 26128     coursereps@le.ac.uk  23/09/2024 10:29   Unknown   Unknown      Html
#
# [26129 rows x 5 columns]

# %%
df_clicksmatriculation.head()
# Out:
#    NumClicks  NumClicks.1                   Email EmailType Firstname  \
# 0          1            1   rds30@leicester.ac.uk      Html    Robert
# 1          1            1    hbi2@leicester.ac.uk      Html     Harry
# 2          1            1  aae16@student.le.ac.uk      Html       NaN
# 3          1            1  lcb30@student.le.ac.uk      Html       NaN
# 4          1            1  slr40@student.le.ac.uk      Html       NaN
#
#     Lastname
# 0     Sulley
# 1  Brown Iii
# 2        NaN
# 3        NaN
# 4        NaN

# %%
df_clicksmatriculation.duplicated().sum()
# Out:
# 0

# %%
df_clicksmatriculation.isnull().sum()
# Out:
# NumClicks        0
# NumClicks.1      0
# Email            0
# EmailType        0
# Firstname      526
# Lastname       527
# dtype: int64

# %%
df_clicksmatriculation["Firstname"] = df_clicksmatriculation["Firstname"].fillna("Unknown")
df_clicksmatriculation["Lastname"] = df_clicksmatriculation["Lastname"].fillna("Unknown")
df_clicksmatriculation
# Out:
#      NumClicks  NumClicks.1                   Email EmailType Firstname  \
# 0            1            1   rds30@leicester.ac.uk      Html    Robert
# 1            1            1    hbi2@leicester.ac.uk      Html     Harry
# 2            1            1  aae16@student.le.ac.uk      Html   Unknown
# 3            1            1  lcb30@student.le.ac.uk      Html   Unknown
# 4            1            1  slr40@student.le.ac.uk      Html   Unknown
# ..         ...          ...                     ...       ...       ...
# 526          1            1  ea344@student.le.ac.uk      Html   Unknown
# 527          2            2   fn69@student.le.ac.uk      Html   Unknown
# 528          1            1   bdc6@student.le.ac.uk      Html   Unknown
# 529          1            1  amm106@leicester.ac.uk      Html   Unknown
# 530          1            1  am1412@leicester.ac.uk      Html   Unknown
#
#       Lastname
# 0       Sulley
# 1    Brown Iii
# 2      Unknown
# 3      Unknown
# 4      Unknown
# ...

# %%
df_clicksSUCarnival.head()
# Out:
#    NumClicks  NumClicks.1                   Email EmailType Firstname Lastname
# 0          2            2    ak11@leicester.ac.uk      Html       NaN      NaN
# 1          4            4  nw176@student.le.ac.uk      Html       NaN      NaN
# 2          1            1  soa18@student.le.ac.uk      Html       NaN      NaN
# 3          1            1   ldz1@student.le.ac.uk      Html       NaN      NaN
# 4          1            1   dk266@leicester.ac.uk      Html     Didem   Karaer

# %%
df_clicksSUCarnival.duplicated().sum()
# Out:
# 0

# %%
df_clicksSUCarnival.isnull().sum()
# Out:
# NumClicks        0
# NumClicks.1      0
# Email            0
# EmailType        0
# Firstname      358
# Lastname       361
# dtype: int64

# %%
df_clicksSUCarnival["Firstname"] = df_clicksSUCarnival["Firstname"].fillna("Unknown")
df_clicksSUCarnival["Lastname"] = df_clicksSUCarnival["Lastname"].fillna("Unknown")
df_clicksSUCarnival
# Out:
#      NumClicks  NumClicks.1                   Email EmailType Firstname  \
# 0            2            2    ak11@leicester.ac.uk      Html   Unknown
# 1            4            4  nw176@student.le.ac.uk      Html   Unknown
# 2            1            1  soa18@student.le.ac.uk      Html   Unknown
# 3            1            1   ldz1@student.le.ac.uk      Html   Unknown
# 4            1            1   dk266@leicester.ac.uk      Html     Didem
# ..         ...          ...                     ...       ...       ...
# 359          1            1  pah36@student.le.ac.uk      Html   Unknown
# 360          1            1  km572@student.le.ac.uk      Html   Unknown
# 361          1            1  am1412@leicester.ac.uk      Html   Unknown
# 362          1            1   rmds1@leicester.ac.uk      Html   Unknown
# 363          1            1  zl302@student.le.ac.uk      Html   Unknown
#
#     Lastname
# 0    Unknown
# 1    Unknown
# 2    Unknown
# 3    Unknown
# 4     Karaer
# ..       ...
# ...

# %%
df_clicksVintagesale.head()
# Out:
#    NumClicks  NumClicks.1                   Email EmailType Firstname Lastname
# 0          1            1   ore2@student.le.ac.uk      Html       NaN      NaN
# 1          1            1  rf193@student.le.ac.uk      Html       NaN      NaN
# 2          1            1   pavs2@leicester.ac.uk      Html      Paul     Shaw
# 3          2            2    lfa7@leicester.ac.uk      Html     Lukas     Adam
# 4          1            1   lal19@leicester.ac.uk      Html       NaN      NaN

# %%
df_clicksVintagesale.duplicated().sum()
# Out:
# 0

# %%
df_clicksVintagesale.isnull().sum()
# Out:
# NumClicks        0
# NumClicks.1      0
# Email            0
# EmailType        0
# Firstname      219
# Lastname       220
# dtype: int64

# %%
df_clicksVintagesale["Firstname"] = df_clicksVintagesale["Firstname"].fillna("Unknown")
df_clicksVintagesale["Lastname"] = df_clicksVintagesale["Lastname"].fillna("Unknown")
df_clicksVintagesale
# Out:
#      NumClicks  NumClicks.1                   Email EmailType Firstname  \
# 0            1            1   ore2@student.le.ac.uk      Html   Unknown
# 1            1            1  rf193@student.le.ac.uk      Html   Unknown
# 2            1            1   pavs2@leicester.ac.uk      Html      Paul
# 3            2            2    lfa7@leicester.ac.uk      Html     Lukas
# 4            1            1   lal19@leicester.ac.uk      Html   Unknown
# ..         ...          ...                     ...       ...       ...
# 218          2            2  lw405@student.le.ac.uk      Html   Unknown
# 219          1            1   wg72@student.le.ac.uk      Html   Unknown
# 220          1            1  kjm54@student.le.ac.uk      Html   Unknown
# 221          1            1  aj394@student.le.ac.uk      Html   Unknown
# 222          1            1   yag3@student.le.ac.uk      Html   Unknown
#
#     Lastname
# 0    Unknown
# 1    Unknown
# 2       Shaw
# 3       Adam
# 4    Unknown
# ..       ...
# ...

# %%
df_recepient_clickslink.head()
# Out:
#                     Email  Html                                         Url  \
# 0   nm365@leicester.ac.uk  True  https://www.instagram.com/leicstudentlife/
# 1   nm365@leicester.ac.uk  True                         http://www.le.ac.uk
# 2  rmaw3@student.le.ac.uk  True       https://le.ac.uk/study/welcome/events
# 3  rmaw3@student.le.ac.uk  True       https://le.ac.uk/study/welcome/events
# 4   rds30@leicester.ac.uk  True       https://le.ac.uk/study/welcome/events
#
#         DateClicked                                          UserAgent  \
# 0  23/09/2024 16:36  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 1  23/09/2024 16:36  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 2  25/09/2024 18:52  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...
# 3  25/09/2024 18:51  Mozilla/5.0 (iPhone; CPU iPhone OS 17_6_1 like...
# 4  23/09/2024 20:36  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...
#
#                IP                    Keyword LinkGroups
# ...

# %%
df_recepient_clickslink.duplicated().sum()
# Out:
# 42

# %%
df_recepient_clickslink.drop_duplicates()
# Out:
#                            Email  Html  \
# 0          nm365@leicester.ac.uk  True
# 1          nm365@leicester.ac.uk  True
# 2         rmaw3@student.le.ac.uk  True
# 3         rmaw3@student.le.ac.uk  True
# 4          rds30@leicester.ac.uk  True
# ...                          ...   ...
# 2206  lisa.smith@leicester.ac.uk  True
# 2207  lisa.smith@leicester.ac.uk  True
# 2208       sjca2@leicester.ac.uk  True
# 2210       tjb47@leicester.ac.uk  True
# 2211       tjb47@leicester.ac.uk  True
#
#                                                     Url       DateClicked  \
# 0            https://www.instagram.com/leicstudentlife/  23/09/2024 16:36
# 1                                   http://www.le.ac.uk  23/09/2024 16:36
# 2                 https://le.ac.uk/study/welcome/events  25/09/2024 18:52
# 3                 https://le.ac.uk/study/welcome/events  25/09/2024 18:51
# 4                 https://le.ac.uk/study/welcome/events  23/09/2024 20:36
# ...

# %%
df_recepient_clickslink.isnull().sum()
# Out:
# Email            0
# Html             0
# Url              0
# DateClicked      0
# UserAgent        0
# IP               0
# Keyword        124
# LinkGroups     124
# dtype: int64

# %%
df_recepient_clickslink["Keyword"] = df_recepient_clickslink["Keyword"].fillna("Unknown")
df_recepient_clickslink["LinkGroups"] = df_recepient_clickslink["LinkGroups"].fillna("Unknown")
df_recepient_clickslink
# Out:
#                            Email  Html  \
# 0          nm365@leicester.ac.uk  True
# 1          nm365@leicester.ac.uk  True
# 2         rmaw3@student.le.ac.uk  True
# 3         rmaw3@student.le.ac.uk  True
# 4          rds30@leicester.ac.uk  True
# ...                          ...   ...
# 2207  lisa.smith@leicester.ac.uk  True
# 2208       sjca2@leicester.ac.uk  True
# 2209       sjca2@leicester.ac.uk  True
# 2210       tjb47@leicester.ac.uk  True
# 2211       tjb47@leicester.ac.uk  True
#
#                                                     Url       DateClicked  \
# 0            https://www.instagram.com/leicstudentlife/  23/09/2024 16:36
# 1                                   http://www.le.ac.uk  23/09/2024 16:36
# 2                 https://le.ac.uk/study/welcome/events  25/09/2024 18:52
# 3                 https://le.ac.uk/study/welcome/events  25/09/2024 18:51
# 4                 https://le.ac.uk/study/welcome/events  23/09/2024 20:36
# ...

# %%
def total_opens():
    total_opens = df_emailopened["NumOpens"].sum()
    print("Total number of NumOpens: ", total_opens)



total_opens()
# Out:
# Total number of NumOpens:  27371

# %%
average_opens = df_emailopened["NumOpens"].mean()
df_emailopened["AverageNumOpens"] = average_opens

print("Average number of NumOpens:", average_opens)
# Out:
# Average number of NumOpens: 2.114570457354759

# %%
minimum_opens = df_emailopened["NumOpens"].min()
df_emailopened["MinimumOpens"] = minimum_opens
print("Minimum number of NumOpens: ", minimum_opens)
# Out:
# Minimum number of NumOpens:  1

# %%
maximum_opens = df_emailopened["NumOpens"].max()
print("Maximum number of NumOpens: ", maximum_opens)
# Out:
# Maximum number of NumOpens:  23

# %%
df_emailopened["DateOpened"] = pd.to_datetime(df_emailopened["DateOpened"], format="%d/%m/%Y %H:%M") #convert string to datetime

# %%
df_emailopened["DateOpenedLast"] = pd.to_datetime(df_emailopened["DateOpenedLast"], format="%d/%m/%Y %H:%M") #convert string to datetime

# %%
df_emailopened["EngagementSpan"] = df_emailopened["DateOpenedLast"] - df_emailopened["DateOpened"]
df_emailopened.head(10)
# Out:
#    NumOpens                    Email EmailType          DateOpened  \
# 0         2    ucn1@student.le.ac.uk      Html 2024-09-23 10:42:00
# 1         2    vdg2@student.le.ac.uk      Html 2024-09-24 01:03:00
# 2         1   dcc26@student.le.ac.uk      Html 2024-09-26 02:20:00
# 3         2   hc365@student.le.ac.uk      Html 2024-09-23 11:21:00
# 4         1    wlr1@student.le.ac.uk      Html 2024-09-23 13:38:00
# 5         1   shia1@student.le.ac.uk      Html 2024-09-23 13:49:00
# 6         1   cll46@student.le.ac.uk      Html 2024-09-23 22:36:00
# 7         1  ajp120@student.le.ac.uk      Html 2024-09-23 20:32:00
# 8         2   hl351@student.le.ac.uk      Html 2024-09-23 22:55:00
# 9         1    ahaa8@leicester.ac.uk      Html 2024-10-03 20:44:00
#
#        DateOpenedLast  AverageNumOpens  MinimumOpens   EngagementSpan
# 0 2024-09-23 10:42:00          2.11457             1  0 days 00:00:00
# 1 2024-09-25 21:27:00          2.11457             1  1 days 20:24:00
# ...

# %%
df_emailopened["EngagementHours"] = df_emailopened["EngagementSpan"].dt.total_seconds() / 3600
df_emailopened
# Out:
#        NumOpens                     Email EmailType          DateOpened  \
# 0             2     ucn1@student.le.ac.uk      Html 2024-09-23 10:42:00
# 1             2     vdg2@student.le.ac.uk      Html 2024-09-24 01:03:00
# 2             1    dcc26@student.le.ac.uk      Html 2024-09-26 02:20:00
# 3             2    hc365@student.le.ac.uk      Html 2024-09-23 11:21:00
# 4             1     wlr1@student.le.ac.uk      Html 2024-09-23 13:38:00
# ...         ...                       ...       ...                 ...
# 12939         2     lw322@leicester.ac.uk      Html 2024-09-23 12:10:00
# 12940         2  amy.cory@leicester.ac.uk      Html 2024-09-25 12:53:00
# 12941         2    cwm18@student.le.ac.uk      Html 2025-05-29 10:47:00
# 12942         2     fama4@leicester.ac.uk      Html 2024-09-23 13:37:00
# 12943         3       coursereps@le.ac.uk      Html 2024-09-23 10:30:00
#
#            DateOpenedLast  AverageNumOpens  MinimumOpens   EngagementSpan  \
# ...

# %%
def numopen_level_classification(opens): #categorising open levels into different categories
    if opens <= 1:
        return 'Low'
    elif opens <= 4:
        return 'Medium'
    else:
        return 'High'

# %%
df_emailopened["Openlevel"] = df_emailopened["NumOpens"].apply(numopen_level_classification)
df_emailopened
# Out:
#        NumOpens                     Email EmailType          DateOpened  \
# 0             2     ucn1@student.le.ac.uk      Html 2024-09-23 10:42:00
# 1             2     vdg2@student.le.ac.uk      Html 2024-09-24 01:03:00
# 2             1    dcc26@student.le.ac.uk      Html 2024-09-26 02:20:00
# 3             2    hc365@student.le.ac.uk      Html 2024-09-23 11:21:00
# 4             1     wlr1@student.le.ac.uk      Html 2024-09-23 13:38:00
# ...         ...                       ...       ...                 ...
# 12939         2     lw322@leicester.ac.uk      Html 2024-09-23 12:10:00
# 12940         2  amy.cory@leicester.ac.uk      Html 2024-09-25 12:53:00
# 12941         2    cwm18@student.le.ac.uk      Html 2025-05-29 10:47:00
# 12942         2     fama4@leicester.ac.uk      Html 2024-09-23 13:37:00
# 12943         3       coursereps@le.ac.uk      Html 2024-09-23 10:30:00
#
#            DateOpenedLast  AverageNumOpens  MinimumOpens   EngagementSpan  \
# ...

# %%
df_emailopened["Openlevel"].value_counts().plot(kind='bar', title='Email Engagement Levels')
plt.ylabel("Number of People")
plt.show()
df_emailopened["Openlevel"].value_counts()
#high levels of medium open level
#low levels of high open level
# Out:
# Medium    7924
# Low       4366
# High       654
# Name: Openlevel, dtype: int64

# %%
df_emailopened.groupby("EmailType")["AverageNumOpens"].mean().plot(kind="bar", title="Average Opens per Email Type")
plt.ylabel("Average Opens")
plt.show()
df_emailopened.groupby("EmailType")["AverageNumOpens"].value_counts()
# Out:
# EmailType  AverageNumOpens
# Html       2.11457            12944
# Name: AverageNumOpens, dtype: int64

# %%
# Bin the data into 10 bins using pd.cut
bins = pd.cut(df_emailopened['EngagementHours'], bins=10).value_counts().sort_index()
print(bins)

df_emailopened['EngagementHours'].plot(kind='hist', bins=10, title='Distribution of Engagement Hours')
plt.show()

#timeframe of engagement hours (timeframe email is opened), frequency == amount of people
# Out:
# (-6.894, 689.44]      12652
# (689.44, 1378.88]       117
# (1378.88, 2068.32]       42
# (2068.32, 2757.76]       31
# (2757.76, 3447.2]        23
# (3447.2, 4136.64]        22
# (4136.64, 4826.08]       22
# (4826.08, 5515.52]       12
# (5515.52, 6204.96]       15
# (6204.96, 6894.4]         8
# Name: EngagementHours, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(
    x='Openlevel',
    y='EngagementHours',
    data=df_emailopened,
    boxprops=dict(facecolor='white', edgecolor='black'),
    whiskerprops=dict(color='black'),
    capprops=dict(color='black'),
    medianprops=dict(color='black'),
    flierprops=dict(marker='o', color='black', alpha=0.3, markersize=3),
    showfliers=True
)

plt.yscale('log')  #log scale to handle skewed data
plt.title('Engagement Span by Open Level (Log Scale)')
plt.grid(True, which="both", axis='y', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()


sns.boxplot(x='Openlevel', y='EngagementHours', data=df_emailopened).set_title('Engagement Span by Open Level')

df_emailopened.groupby("Openlevel")["EngagementHours"].std()
# Out:
# Openlevel
# High      1024.600547
# Low          0.000000
# Medium     471.391937
# Name: EngagementHours, dtype: float64

# %%
##most and least clicked links

def total_clicks():
    total_clicksmatriculation = df_clicksmatriculation["NumClicks"].sum()
    print("Total number of NumClicks for https://le.ac.uk/study/welcome/events : ", total_clicksmatriculation)
    
    total_clicksSUCarnival = df_clicksSUCarnival["NumClicks"].sum()
    print("Total number of NumClicks for https://le.ac.uk/study/welcome/events : ",  total_clicksSUCarnival)
    

    total_clicksVintagesale = df_clicksVintagesale["NumClicks"].sum()
    print("Total number of NumClicks for https://le.ac.uk/study/welcome/events ",  total_clicksVintagesale)
    
    
    
    
    



total_clicks()
# Out:
# Total number of NumClicks for https://le.ac.uk/study/welcome/events :  656
# Total number of NumClicks for https://le.ac.uk/study/welcome/events :  452
# Total number of NumClicks for https://le.ac.uk/study/welcome/events  272

# %%
import sqlite3

# %%
df_emailopened = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September232024/The-Citizen-What-s-on-Monday-23-September-2024-️EmailOpened.csv")

# %%
conn = sqlite3.connect("stanleyykfdb.db")

# %%
df_emailopened.to_sql("emailopened", conn, if_exists="replace", index=False)
# Out:
# 12944

# %%
result = pd.read_sql_query("SELECT COUNT(*) FROM emailopened; ", conn)
print(result)
# Out:
#    COUNT(*)
# 0     12944
