# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from datetime import datetime

# %%
df_emailopened = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September242024/The-Citizen-What-s-on-Tuesday-24-September-2024-EmailOpened.csv")

df_emailsends = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September242024/The-Citizen-What-s-on-Tuesday-24-September-2024-EmailSends.csv")

df_clicksFreebiesFair = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September242024/The-Citizen-What-s-on-Tuesday-24-September-2024-Link-clicksFreebies Fair.csv")

df_clicksIndomienoodles = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September242024/The-Citizen-What-s-on-Tuesday-24-September-2024-Link-clicksIndomie noodles.csv")

df_clicksPlantsale = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September242024/The-Citizen-What-s-on-Tuesday-24-September-2024-Link-clicksPlant sale.csv")

df_recepient_clickslink = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September242024/The-Citizen-What-s-on-Tuesday-24-September-2024-Recipient-clickslink.csv")

# %%
df_emailopened.head()
# Out:
#    NumOpens                   Email EmailType        DateOpened  \
# 0         1   ucn1@student.le.ac.uk      Html  24/09/2024 09:55
# 1         1   vdg2@student.le.ac.uk      Html  25/09/2024 03:57
# 2         1  dcc26@student.le.ac.uk      Html  26/09/2024 02:20
# 3         2  hc365@student.le.ac.uk      Html  24/09/2024 11:57
# 4         1  cll46@student.le.ac.uk      Html  24/09/2024 14:32
#
#      DateOpenedLast
# 0  24/09/2024 09:55
# 1  25/09/2024 03:57
# 2  26/09/2024 02:20
# 3  24/09/2024 17:23
# 4  24/09/2024 14:32

# %%
df_emailsends.value_counts()
# Out:
# Email                    DateSent          Firstname        Lastname          EmailType
# aa1034@leicester.ac.uk   24/09/2024 09:54  Ahmad            Abouelnour        Html         1
# ndj11@leicester.ac.uk    24/09/2024 09:54  Nicholas         Janicki           Html         1
# ms1165@leicester.ac.uk   24/09/2024 09:54  Mariella         Scerri            Html         1
# ms1246@student.le.ac.uk  24/09/2024 09:55  Melody           Saya              Html         1
# msa52@student.le.ac.uk   24/09/2024 09:54  Megan            STAFFORD-ADATIA   Html         1
#                                                                                           ..
# gip2@leicester.ac.uk     24/09/2024 09:54  Georgia          Parsisson         Html         1
# gk214@student.le.ac.uk   24/09/2024 09:54  Grace Susannah   KLEMPERER         Html         1
# gm239@leicester.ac.uk    24/09/2024 09:55  Luca             Moliterni         Html         1
# gmf13@student.le.ac.uk   24/09/2024 09:54  Guilherme        Muiños Filgueira  Html         1
# zyl6@leicester.ac.uk     24/09/2024 09:55  Zi               Liao              Html         1
# Length: 655, dtype: int64

# %%
df_emailopened.duplicated().sum()
# Out:
# 0

# %%
df_emailopened.isnull().sum()
# Out:
# NumOpens          0
# Email             0
# EmailType         0
# DateOpened        0
# DateOpenedLast    0
# dtype: int64

# %%
df_emailsends.head()
# Out:
#                     Email          DateSent Firstname Lastname EmailType
# 0   ucn1@student.le.ac.uk  24/09/2024 09:54       NaN      NaN      Html
# 1  jlpc1@student.le.ac.uk  24/09/2024 09:55       NaN      NaN      Html
# 2  jg562@student.le.ac.uk  24/09/2024 09:55       NaN      NaN      Html
# 3   vdg2@student.le.ac.uk  24/09/2024 09:54       NaN      NaN      Html
# 4  dcc26@student.le.ac.uk  24/09/2024 09:55       NaN      NaN      Html

# %%
df_emailsends.duplicated().sum()
# Out:
# 0

# %%
df_emailsends.isnull().sum()
# Out:
# Email            0
# DateSent         0
# Firstname    25528
# Lastname     25607
# EmailType        0
# dtype: int64

# %%
df_emailsends['Firstname'] = df_emailsends['Firstname'].fillna('Unknown')
df_emailsends['Lastname'] = df_emailsends['Lastname'].fillna('Unknown')
df_emailsends
# Out:
#                         Email          DateSent Firstname  Lastname EmailType
# 0       ucn1@student.le.ac.uk  24/09/2024 09:54   Unknown   Unknown      Html
# 1      jlpc1@student.le.ac.uk  24/09/2024 09:55   Unknown   Unknown      Html
# 2      jg562@student.le.ac.uk  24/09/2024 09:55   Unknown   Unknown      Html
# 3       vdg2@student.le.ac.uk  24/09/2024 09:54   Unknown   Unknown      Html
# 4      dcc26@student.le.ac.uk  24/09/2024 09:55   Unknown   Unknown      Html
# ...                       ...               ...       ...       ...       ...
# 26257  cwm18@student.le.ac.uk  24/09/2024 09:55   Unknown   Unknown      Html
# 26258   zo17@student.le.ac.uk  24/09/2024 09:55   Unknown   Unknown      Html
# 26259   fama4@leicester.ac.uk  24/09/2024 09:54   Fatimah  Alsaiari      Html
# 26260   kh370@leicester.ac.uk  24/09/2024 09:54  Karianne    Hansen      Html
# 26261     coursereps@le.ac.uk  24/09/2024 09:54   Unknown   Unknown      Html
#
# [26262 rows x 5 columns]

# %%
df_clicksFreebiesFair.head()
# Out:
#    NumClicks  NumClicks.1                    Email EmailType Firstname  \
# 0          1            1   ssn11@student.le.ac.uk      Html       NaN
# 1          1            1   ajt50@student.le.ac.uk      Html       NaN
# 2          1            1   sn298@student.le.ac.uk      Html       NaN
# 3          1            1  ss1202@student.le.ac.uk      Html  Safooraa
# 4          1            1   gk180@student.le.ac.uk      Html       NaN
#
#   Lastname
# 0      NaN
# 1      NaN
# 2      NaN
# 3    Sajee
# 4      NaN

# %%
df_clicksFreebiesFair.duplicated().sum()
# Out:
# 0

# %%
df_clicksFreebiesFair.isnull().sum()
# Out:
# NumClicks        0
# NumClicks.1      0
# Email            0
# EmailType        0
# Firstname      499
# Lastname       503
# dtype: int64

# %%
df_clicksFreebiesFair['Firstname'] = df_clicksFreebiesFair['Firstname'].fillna('Unknown')
df_clicksFreebiesFair['Lastname'] = df_clicksFreebiesFair['Lastname'].fillna('Unknown')
df_clicksFreebiesFair
# Out:
#      NumClicks  NumClicks.1                    Email EmailType Firstname  \
# 0            1            1   ssn11@student.le.ac.uk      Html   Unknown
# 1            1            1   ajt50@student.le.ac.uk      Html   Unknown
# 2            1            1   sn298@student.le.ac.uk      Html   Unknown
# 3            1            1  ss1202@student.le.ac.uk      Html  Safooraa
# 4            1            1   gk180@student.le.ac.uk      Html   Unknown
# ..         ...          ...                      ...       ...       ...
# 500          1            1    dts16@leicester.ac.uk      Html   Unknown
# 501          1            1   am1412@leicester.ac.uk      Html   Unknown
# 502          1            1    rmds1@leicester.ac.uk      Html   Unknown
# 503          1            1    vmss2@leicester.ac.uk      Html   Unknown
# 504          1            1   ds808@student.le.ac.uk      Html   Unknown
#
#     Lastname
# 0    Unknown
# 1    Unknown
# 2    Unknown
# 3      Sajee
# 4    Unknown
# ..       ...
# 500  Unknown
# 501  Unknown
# 502  Unknown
# 503  Unknown
# 504  Unknown
#
# [505 rows x 6 columns]

# %%
df_clicksIndomienoodles.head()
# Out:
#    NumClicks  NumClicks.1                   Email EmailType  Firstname  \
# 0          1            1   ldz1@student.le.ac.uk      Html        NaN
# 1          2            2  ma871@student.le.ac.uk      Html        NaN
# 2          1            1  hg188@student.le.ac.uk      Html        NaN
# 3          1            1  kg255@student.le.ac.uk      Html        NaN
# 4          1            1  ft108@student.le.ac.uk      Html        NaN
#
#    Lastname
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN

# %%
df_clicksIndomienoodles.duplicated().sum()
# Out:
# 0

# %%
df_clicksIndomienoodles.isnull().sum()
# Out:
# NumClicks       0
# NumClicks.1     0
# Email           0
# EmailType       0
# Firstname      85
# Lastname       85
# dtype: int64

# %%
df_clicksIndomienoodles['Firstname'] = df_clicksIndomienoodles['Firstname'].fillna('Unknown')
df_clicksIndomienoodles['Lastname'] = df_clicksIndomienoodles['Lastname'].fillna('Unknown')
df_clicksIndomienoodles
# Out:
#     NumClicks  NumClicks.1                    Email EmailType Firstname  \
# 0           1            1    ldz1@student.le.ac.uk      Html   Unknown
# 1           2            2   ma871@student.le.ac.uk      Html   Unknown
# 2           1            1   hg188@student.le.ac.uk      Html   Unknown
# 3           1            1   kg255@student.le.ac.uk      Html   Unknown
# 4           1            1   ft108@student.le.ac.uk      Html   Unknown
# ..        ...          ...                      ...       ...       ...
# 80          1            1   jfs14@student.le.ac.uk      Html   Unknown
# 81          1            1   sr624@student.le.ac.uk      Html   Unknown
# 82          1            1  sm1196@student.le.ac.uk      Html   Unknown
# 83          1            1    zlw1@student.le.ac.uk      Html   Unknown
# 84          1            1   ds808@student.le.ac.uk      Html   Unknown
#
#    Lastname
# 0   Unknown
# 1   Unknown
# 2   Unknown
# 3   Unknown
# 4   Unknown
# ..      ...
# 80  Unknown
# 81  Unknown
# 82  Unknown
# 83  Unknown
# 84  Unknown
#
# [85 rows x 6 columns]

# %%
df_clicksPlantsale.head()
# Out:
#    NumClicks  NumClicks.1                  Email EmailType Firstname Lastname
# 0          1            1  lh389@leicester.ac.uk      Html       NaN      NaN
# 1          2            2  ore2@student.le.ac.uk      Html       NaN      NaN
# 2          2            2  aea20@leicester.ac.uk      Html       NaN      NaN
# 3          2            2  slf36@leicester.ac.uk      Html       NaN      NaN
# 4          1            1  lal19@leicester.ac.uk      Html       NaN      NaN

# %%
df_clicksPlantsale.duplicated().sum()
# Out:
# 0

# %%
df_clicksPlantsale.isnull().sum()
# Out:
# NumClicks        0
# NumClicks.1      0
# Email            0
# EmailType        0
# Firstname      206
# Lastname       209
# dtype: int64

# %%
df_clicksPlantsale['Firstname'] = df_clicksPlantsale['Firstname'].fillna('Unknown')
df_clicksPlantsale['Lastname'] = df_clicksPlantsale['Lastname'].fillna('Unknown')
df_clicksPlantsale
# Out:
#      NumClicks  NumClicks.1                    Email EmailType Firstname  \
# 0            1            1    lh389@leicester.ac.uk      Html   Unknown
# 1            2            2    ore2@student.le.ac.uk      Html   Unknown
# 2            2            2    aea20@leicester.ac.uk      Html   Unknown
# 3            2            2    slf36@leicester.ac.uk      Html   Unknown
# 4            1            1    lal19@leicester.ac.uk      Html   Unknown
# ..         ...          ...                      ...       ...       ...
# 207          3            3   km572@student.le.ac.uk      Html   Unknown
# 208          2            2    ok73@student.le.ac.uk      Html   Unknown
# 209          1            1   am1412@leicester.ac.uk      Html   Unknown
# 210          1            1  js1241@student.le.ac.uk      Html   Unknown
# 211          1            1    sia15@leicester.ac.uk      Html   Unknown
#
#     Lastname
# 0    Unknown
# 1    Unknown
# 2    Unknown
# 3    Unknown
# 4    Unknown
# ..       ...
# 207  Unknown
# 208  Unknown
# 209  Unknown
# 210  Unknown
# 211  Unknown
#
# [212 rows x 6 columns]

# %%
df_recepient_clickslink.head()
# Out:
#                     Email  Html  \
# 0   mar68@leicester.ac.uk  True
# 1  jee16@student.le.ac.uk  True
# 2  xc176@student.le.ac.uk  True
# 3  xc176@student.le.ac.uk  True
# 4   lh389@leicester.ac.uk  True
#
#                                                  Url       DateClicked  \
# 0                                http://www.le.ac.uk  24/09/2024 10:03
# 1  https://www.visitleicester.info/whats-on/from-...  24/09/2024 15:21
# 2                                http://www.le.ac.uk  24/09/2024 09:59
# 3                                http://www.le.ac.uk  24/09/2024 09:59
# 4              https://le.ac.uk/study/welcome/events  24/09/2024 10:18
#
#                                            UserAgent               IP  \
# 0  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  143.210.130.124
# 1  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...    92.236.45.146
# 2  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...    52.138.212.99
# 3  Mozilla/5.0 (iPhone; CPU iPhone OS 17_6_1 like...    223.74.87.203
# 4  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  143.210.191.139
#
#                Keyword LinkGroups
# 0                  NaN        NaN
# 1  From Dusk Till Dawn     Events
# 2                  NaN        NaN
# 3                  NaN        NaN
# 4           Plant sale     Events

# %%
df_recepient_clickslink.duplicated().sum()
# Out:
# 16

# %%
df_recepient_clickslink.drop_duplicates()
# Out:
#                        Email   Html  \
# 0      mar68@leicester.ac.uk   True
# 1     jee16@student.le.ac.uk   True
# 2     xc176@student.le.ac.uk   True
# 3     xc176@student.le.ac.uk   True
# 4      lh389@leicester.ac.uk   True
# ...                      ...    ...
# 1570  goo10@student.le.ac.uk  False
# 1571  goo10@student.le.ac.uk  False
# 1572  goo10@student.le.ac.uk  False
# 1573  goo10@student.le.ac.uk  False
# 1574   fama4@leicester.ac.uk   True
#
#                                                     Url       DateClicked  \
# 0                                   http://www.le.ac.uk  24/09/2024 10:03
# 1     https://www.visitleicester.info/whats-on/from-...  24/09/2024 15:21
# 2                                   http://www.le.ac.uk  24/09/2024 09:59
# 3                                   http://www.le.ac.uk  24/09/2024 09:59
# 4                 https://le.ac.uk/study/welcome/events  24/09/2024 10:18
# ...                                                 ...               ...
# 1570              https://forms.office.com/e/fP2pnz1t6g  24/09/2024 09:57
# 1571           https://www.instagram.com/p/C7wmlC6NoV-/  24/09/2024 09:57
# 1572  https://le.ac.uk/about/conflict-support/israel...  24/09/2024 09:57
# 1573         https://www.instagram.com/leicstudentlife/  24/09/2024 09:57
# 1574              https://le.ac.uk/study/welcome/events  25/09/2024 18:43
#
#                                               UserAgent               IP  \
# 0     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  143.210.130.124
# 1     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...    92.236.45.146
# 2     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...    52.138.212.99
# 3     Mozilla/5.0 (iPhone; CPU iPhone OS 17_6_1 like...    223.74.87.203
# 4     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  143.210.191.139
# ...                                                 ...              ...
# 1570  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...     168.63.15.65
# 1571  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...     168.63.15.65
# 1572  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...     168.63.15.65
# 1573  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...     168.63.15.65
# 1574  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...   188.53.208.109
#
#                                Keyword LinkGroups
# 0                                  NaN        NaN
# 1                  From Dusk Till Dawn     Events
# 2                                  NaN        NaN
# 3                                  NaN        NaN
# 4                           Plant sale     Events
# ...                                ...        ...
# 1570            Support: Questionnaire    Support
# 1571  Events: Riverside Festival recap     Events
# 1572     Support: Israel and Palestine    Support
# 1573                               NaN        NaN
# 1574                     Matriculation     Events
#
# [1559 rows x 8 columns]

# %%
df_recepient_clickslink.isnull().sum()
# Out:
# Email           0
# Html            0
# Url             0
# DateClicked     0
# UserAgent       0
# IP              0
# Keyword        87
# LinkGroups     87
# dtype: int64

# %%
df_recepient_clickslink["Keyword"] = df_recepient_clickslink["Keyword"].fillna("Unknown")
df_recepient_clickslink["LinkGroups"] = df_recepient_clickslink["LinkGroups"].fillna("Unknown")
df_recepient_clickslink
# Out:
#                        Email   Html  \
# 0      mar68@leicester.ac.uk   True
# 1     jee16@student.le.ac.uk   True
# 2     xc176@student.le.ac.uk   True
# 3     xc176@student.le.ac.uk   True
# 4      lh389@leicester.ac.uk   True
# ...                      ...    ...
# 1570  goo10@student.le.ac.uk  False
# 1571  goo10@student.le.ac.uk  False
# 1572  goo10@student.le.ac.uk  False
# 1573  goo10@student.le.ac.uk  False
# 1574   fama4@leicester.ac.uk   True
#
#                                                     Url       DateClicked  \
# 0                                   http://www.le.ac.uk  24/09/2024 10:03
# 1     https://www.visitleicester.info/whats-on/from-...  24/09/2024 15:21
# 2                                   http://www.le.ac.uk  24/09/2024 09:59
# 3                                   http://www.le.ac.uk  24/09/2024 09:59
# 4                 https://le.ac.uk/study/welcome/events  24/09/2024 10:18
# ...                                                 ...               ...
# 1570              https://forms.office.com/e/fP2pnz1t6g  24/09/2024 09:57
# 1571           https://www.instagram.com/p/C7wmlC6NoV-/  24/09/2024 09:57
# 1572  https://le.ac.uk/about/conflict-support/israel...  24/09/2024 09:57
# 1573         https://www.instagram.com/leicstudentlife/  24/09/2024 09:57
# 1574              https://le.ac.uk/study/welcome/events  25/09/2024 18:43
#
#                                               UserAgent               IP  \
# 0     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  143.210.130.124
# 1     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...    92.236.45.146
# 2     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...    52.138.212.99
# 3     Mozilla/5.0 (iPhone; CPU iPhone OS 17_6_1 like...    223.74.87.203
# 4     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  143.210.191.139
# ...                                                 ...              ...
# 1570  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...     168.63.15.65
# 1571  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...     168.63.15.65
# 1572  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...     168.63.15.65
# 1573  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...     168.63.15.65
# 1574  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...   188.53.208.109
#
#                                Keyword LinkGroups
# 0                              Unknown    Unknown
# 1                  From Dusk Till Dawn     Events
# 2                              Unknown    Unknown
# 3                              Unknown    Unknown
# 4                           Plant sale     Events
# ...                                ...        ...
# 1570            Support: Questionnaire    Support
# 1571  Events: Riverside Festival recap     Events
# 1572     Support: Israel and Palestine    Support
# 1573                           Unknown    Unknown
# 1574                     Matriculation     Events
#
# [1575 rows x 8 columns]

# %%
def total_opens():
    total_opens = df_emailopened["NumOpens"].sum()
    print("Total number of NumOpens: ", total_opens)



total_opens()
# Out:
# Total number of NumOpens:  24677

# %%
average_opens = df_emailopened["NumOpens"].mean()
df_emailopened["AverageNumOpens"] = average_opens

print("Average number of NumOpens:", average_opens)
# Out:
# Average number of NumOpens: 2.0238661527105717

# %%
minimum_opens = df_emailopened["NumOpens"].min()
df_emailopened["MinimumOpens"] = minimum_opens
print("Minimum number of NumOpens: ", minimum_opens)
# Out:
# Minimum number of NumOpens:  1

# %%
maximum_opens = df_emailopened["NumOpens"].max()
print("Maximum number of NumOpens: ", maximum_opens)
# Out:
# Maximum number of NumOpens:  20

# %%
df_emailopened["DateOpened"] = pd.to_datetime(df_emailopened["DateOpened"], format="%d/%m/%Y %H:%M") #convert string to datetime

# %%
df_emailopened["DateOpenedLast"] = pd.to_datetime(df_emailopened["DateOpenedLast"], format="%d/%m/%Y %H:%M") #convert string to datetime

# %%
df_emailopened["EngagementSpan"] = df_emailopened["DateOpenedLast"] - df_emailopened["DateOpened"]
df_emailopened.head(10)
# Out:
#    NumOpens                    Email EmailType          DateOpened  \
# 0         1    ucn1@student.le.ac.uk      Html 2024-09-24 09:55:00
# 1         1    vdg2@student.le.ac.uk      Html 2024-09-25 03:57:00
# 2         1   dcc26@student.le.ac.uk      Html 2024-09-26 02:20:00
# 3         2   hc365@student.le.ac.uk      Html 2024-09-24 11:57:00
# 4         1   cll46@student.le.ac.uk      Html 2024-09-24 14:32:00
# 5         1  ajp120@student.le.ac.uk      Html 2024-09-24 18:52:00
# 6         1    ahaa8@leicester.ac.uk      Html 2024-10-03 20:44:00
# 7         1    rs802@leicester.ac.uk      Html 2024-09-24 09:55:00
# 8         1    mqma1@leicester.ac.uk      Html 2024-09-24 16:01:00
# 9         3  communications@le.ac.uk      Html 2024-09-24 10:24:00
#
#        DateOpenedLast  AverageNumOpens  MinimumOpens  EngagementSpan
# 0 2024-09-24 09:55:00         2.023866             1 0 days 00:00:00
# 1 2024-09-25 03:57:00         2.023866             1 0 days 00:00:00
# 2 2024-09-26 02:20:00         2.023866             1 0 days 00:00:00
# 3 2024-09-24 17:23:00         2.023866             1 0 days 05:26:00
# 4 2024-09-24 14:32:00         2.023866             1 0 days 00:00:00
# 5 2024-09-24 18:52:00         2.023866             1 0 days 00:00:00
# 6 2024-10-03 20:44:00         2.023866             1 0 days 00:00:00
# 7 2024-09-24 09:55:00         2.023866             1 0 days 00:00:00
# 8 2024-09-24 16:01:00         2.023866             1 0 days 00:00:00
# 9 2024-09-24 16:06:00         2.023866             1 0 days 05:42:00

# %%
df_emailopened["EngagementHours"] = df_emailopened["EngagementSpan"].dt.total_seconds() / 3600
df_emailopened
# Out:
#        NumOpens                     Email EmailType          DateOpened  \
# 0             1     ucn1@student.le.ac.uk      Html 2024-09-24 09:55:00
# 1             1     vdg2@student.le.ac.uk      Html 2024-09-25 03:57:00
# 2             1    dcc26@student.le.ac.uk      Html 2024-09-26 02:20:00
# 3             2    hc365@student.le.ac.uk      Html 2024-09-24 11:57:00
# 4             1    cll46@student.le.ac.uk      Html 2024-09-24 14:32:00
# ...         ...                       ...       ...                 ...
# 12188         3  amy.cory@leicester.ac.uk      Html 2024-09-24 10:21:00
# 12189         2    cwm18@student.le.ac.uk      Html 2025-05-29 10:47:00
# 12190         2     fama4@leicester.ac.uk      Html 2024-09-24 11:08:00
# 12191         2     kh370@leicester.ac.uk      Html 2024-09-24 10:58:00
# 12192         1       coursereps@le.ac.uk      Html 2024-09-24 10:01:00
#
#            DateOpenedLast  AverageNumOpens  MinimumOpens  EngagementSpan  \
# 0     2024-09-24 09:55:00         2.023866             1 0 days 00:00:00
# 1     2024-09-25 03:57:00         2.023866             1 0 days 00:00:00
# 2     2024-09-26 02:20:00         2.023866             1 0 days 00:00:00
# 3     2024-09-24 17:23:00         2.023866             1 0 days 05:26:00
# 4     2024-09-24 14:32:00         2.023866             1 0 days 00:00:00
# ...                   ...              ...           ...             ...
# 12188 2024-09-24 10:22:00         2.023866             1 0 days 00:01:00
# 12189 2025-05-29 10:54:00         2.023866             1 0 days 00:07:00
# 12190 2024-09-25 18:43:00         2.023866             1 1 days 07:35:00
# 12191 2024-09-24 10:58:00         2.023866             1 0 days 00:00:00
# 12192 2024-09-24 10:01:00         2.023866             1 0 days 00:00:00
#
#        EngagementHours
# 0             0.000000
# 1             0.000000
# 2             0.000000
# 3             5.433333
# 4             0.000000
# ...                ...
# 12188         0.016667
# 12189         0.116667
# 12190        31.583333
# 12191         0.000000
# 12192         0.000000
#
# [12193 rows x 9 columns]

# %%
def numopen_level_classification(opens): #categorising open levels into different categories
    if opens <= 1:
        return 'Low'
    elif opens <= 4:
        return 'Medium'
    else:
        return 'High'

# %%
df_emailopened["Openlevel"] = df_emailopened["NumOpens"].apply(numopen_level_classification)
df_emailopened
# Out:
#        NumOpens                     Email EmailType          DateOpened  \
# 0             1     ucn1@student.le.ac.uk      Html 2024-09-24 09:55:00
# 1             1     vdg2@student.le.ac.uk      Html 2024-09-25 03:57:00
# 2             1    dcc26@student.le.ac.uk      Html 2024-09-26 02:20:00
# 3             2    hc365@student.le.ac.uk      Html 2024-09-24 11:57:00
# 4             1    cll46@student.le.ac.uk      Html 2024-09-24 14:32:00
# ...         ...                       ...       ...                 ...
# 12188         3  amy.cory@leicester.ac.uk      Html 2024-09-24 10:21:00
# 12189         2    cwm18@student.le.ac.uk      Html 2025-05-29 10:47:00
# 12190         2     fama4@leicester.ac.uk      Html 2024-09-24 11:08:00
# 12191         2     kh370@leicester.ac.uk      Html 2024-09-24 10:58:00
# 12192         1       coursereps@le.ac.uk      Html 2024-09-24 10:01:00
#
#            DateOpenedLast  AverageNumOpens  MinimumOpens  EngagementSpan  \
# 0     2024-09-24 09:55:00         2.023866             1 0 days 00:00:00
# 1     2024-09-25 03:57:00         2.023866             1 0 days 00:00:00
# 2     2024-09-26 02:20:00         2.023866             1 0 days 00:00:00
# 3     2024-09-24 17:23:00         2.023866             1 0 days 05:26:00
# 4     2024-09-24 14:32:00         2.023866             1 0 days 00:00:00
# ...                   ...              ...           ...             ...
# 12188 2024-09-24 10:22:00         2.023866             1 0 days 00:01:00
# 12189 2025-05-29 10:54:00         2.023866             1 0 days 00:07:00
# 12190 2024-09-25 18:43:00         2.023866             1 1 days 07:35:00
# 12191 2024-09-24 10:58:00         2.023866             1 0 days 00:00:00
# 12192 2024-09-24 10:01:00         2.023866             1 0 days 00:00:00
#
#        EngagementHours Openlevel
# 0             0.000000       Low
# 1             0.000000       Low
# 2             0.000000       Low
# 3             5.433333    Medium
# 4             0.000000       Low
# ...                ...       ...
# 12188         0.016667    Medium
# 12189         0.116667    Medium
# 12190        31.583333    Medium
# 12191         0.000000    Medium
# 12192         0.000000       Low
#
# [12193 rows x 10 columns]

# %%
df_emailopened["Openlevel"].value_counts().plot(kind='bar', title='Email Engagement Levels')
plt.ylabel("Number of People")
plt.show()
df_emailopened["Openlevel"].value_counts()
#high levels of medium open level
#low levels of high open level
# Out:
# Medium    7293
# Low       4380
# High       520
# Name: Openlevel, dtype: int64

# %%
df_emailopened.groupby("EmailType")["AverageNumOpens"].mean().plot(kind="bar", title="Average Opens per Email Type")
plt.ylabel("Average Opens")
plt.show()
df_emailopened.groupby("EmailType")["AverageNumOpens"].value_counts()
# Out:
# EmailType  AverageNumOpens
# Html       2.023866           12193
# Name: AverageNumOpens, dtype: int64

# %%
# Bin the data into 10 bins using pd.cut
bins = pd.cut(df_emailopened['EngagementHours'], bins=10).value_counts().sort_index()
print(bins)

df_emailopened['EngagementHours'].plot(kind='hist', bins=10, title='Distribution of Engagement Hours')
plt.show()

#timeframe of engagement hours (timeframe email is opened), frequency == amount of people
# Out:
# (-6.828, 682.805]      11942
# (682.805, 1365.61]        97
# (1365.61, 2048.415]       35
# (2048.415, 2731.22]       27
# (2731.22, 3414.025]       22
# (3414.025, 4096.83]       27
# (4096.83, 4779.635]       13
# (4779.635, 5462.44]       15
# (5462.44, 6145.245]        9
# (6145.245, 6828.05]        6
# Name: EngagementHours, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(
    x='Openlevel',
    y='EngagementHours',
    data=df_emailopened,
    boxprops=dict(facecolor='white', edgecolor='black'),
    whiskerprops=dict(color='black'),
    capprops=dict(color='black'),
    medianprops=dict(color='black'),
    flierprops=dict(marker='o', color='black', alpha=0.3, markersize=3),
    showfliers=True
)

plt.yscale('log')  #log scale to handle skewed data
plt.title('Engagement Span by Open Level (Log Scale)')
plt.grid(True, which="both", axis='y', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()


sns.boxplot(x='Openlevel', y='EngagementHours', data=df_emailopened).set_title('Engagement Span by Open Level')

df_emailopened.groupby("Openlevel")["EngagementHours"].std()
# Out:
# Openlevel
# High      1008.376037
# Low          0.000000
# Medium     461.027115
# Name: EngagementHours, dtype: float64

# %%
##most and least clicked links

def total_clicks():
    total_clicksFreebiesFair = df_clicksFreebiesFair["NumClicks"].sum()
    print("Total number of NumClicks for https://le.ac.uk/study/welcome/events : ", total_clicksFreebiesFair)
    
    total_clicksIndomienoodles = df_clicksIndomienoodles["NumClicks"].sum()
    print("Total number of NumClicks for https://le.ac.uk/study/welcome/events : ", total_clicksIndomienoodles)
    

    total_clicksPlantsale = df_clicksPlantsale["NumClicks"].sum()
    print("Total number of NumClicks for https://le.ac.uk/study/welcome/events : ",  total_clicksPlantsale)
    
    
    
    
    



total_clicks()
# Out:
# Total number of NumClicks for https://le.ac.uk/study/welcome/events :  620
# Total number of NumClicks for https://le.ac.uk/study/welcome/events :  103
# Total number of NumClicks for https://le.ac.uk/study/welcome/events :  259
