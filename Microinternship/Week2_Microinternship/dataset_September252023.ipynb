# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from datetime import datetime

# %%
df_emailopened = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September252023/Monday-25-September-EmailOpened.csv")

df_emailsends = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September252023/Monday-25-September-EmailSends.csv")

df_clickslaser = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September252023/Monday-25-September-Link-clickslaser.csv")

df_clicksmatriculation = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September252023/Monday-25-September-Link-clicksmatriculation.csv")

df_welcomeevent = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September252023/Monday-25-September-Link-clickswelcomeevents.csv")

df_recepient_clickslink = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September252023/Monday-25-September-Recipient-clickslink.csv")

# %%
df_emailopened.head()
# Out:
#    NumOpens                   Email EmailType        DateOpened  \
# 0         1   ucn1@student.le.ac.uk      Html  02/10/2023 16:34
# 1         1  jg562@student.le.ac.uk      Html  25/10/2023 17:09
# 2         1   vdg2@student.le.ac.uk      Html  26/09/2023 20:58
# 3         1  dcc26@student.le.ac.uk      Html  25/09/2023 12:31
# 4         1  arc39@student.le.ac.uk      Html  08/11/2023 17:31
#
#      DateOpenedLast
# 0  02/10/2023 16:34
# 1  25/10/2023 17:09
# 2  26/09/2023 20:58
# 3  25/09/2023 12:31
# 4  08/11/2023 17:31

# %%
df_emailsends.value_counts()
# Out:
# Email                    DateSent          Firstname  Lastname         EmailType
# aa1034@leicester.ac.uk   25/09/2023 09:00  Ahmad      Abouelnour       Html         1
# nksah1@leicester.ac.uk   25/09/2023 09:00  Noof       Al Harrasi       Html         1
# ms1246@student.le.ac.uk  25/09/2023 09:00  Melody     Saya             Html         1
# msa52@student.le.ac.uk   25/09/2023 09:00  Megan      STAFFORD-ADATIA  Html         1
# msb67@student.le.ac.uk   25/09/2023 09:00  Mahfuza    Begum            Html         1
#                                                                                    ..
# gt165@leicester.ac.uk    25/09/2023 09:00  Gemma      Thompson         Html         1
# gtamh1@leicester.ac.uk   25/09/2023 09:00  Georgia    Marfoh-Hoare     Html         1
# gto2@leicester.ac.uk     25/09/2023 09:00  Gregory    Olsen            Html         1
# ha302@leicester.ac.uk    25/09/2023 09:00  Hesham     Alghamdi         Html         1
# zyl6@leicester.ac.uk     25/09/2023 09:00  Zi         Liao             Html         1
# Length: 907, dtype: int64

# %%
df_emailopened.duplicated().sum()
# Out:
# 0

# %%
df_emailopened.isnull().sum()
# Out:
# NumOpens          0
# Email             0
# EmailType         0
# DateOpened        0
# DateOpenedLast    0
# dtype: int64

# %%
df_emailsends.head()
# Out:
#                     Email          DateSent Firstname Lastname EmailType
# 0   ucn1@student.le.ac.uk  25/09/2023 09:00       NaN      NaN      Html
# 1  jlpc1@student.le.ac.uk  25/09/2023 09:00       NaN      NaN      Html
# 2  jg562@student.le.ac.uk  25/09/2023 09:00       NaN      NaN      Html
# 3   vdg2@student.le.ac.uk  25/09/2023 09:00       NaN      NaN      Html
# 4  dcc26@student.le.ac.uk  25/09/2023 09:00       NaN      NaN      Html

# %%
df_emailsends.duplicated().sum()
# Out:
# 0

# %%
df_emailsends.isnull().sum()
# Out:
# Email            0
# DateSent         0
# Firstname    24498
# Lastname     24593
# EmailType        0
# dtype: int64

# %%
df_emailsends['Firstname'] = df_emailsends['Firstname'].fillna('Unknown')
df_emailsends['Lastname'] = df_emailsends['Lastname'].fillna('Unknown')
df_emailsends
# Out:
#                         Email          DateSent Firstname Lastname EmailType
# 0       ucn1@student.le.ac.uk  25/09/2023 09:00   Unknown  Unknown      Html
# 1      jlpc1@student.le.ac.uk  25/09/2023 09:00   Unknown  Unknown      Html
# 2      jg562@student.le.ac.uk  25/09/2023 09:00   Unknown  Unknown      Html
# 3       vdg2@student.le.ac.uk  25/09/2023 09:00   Unknown  Unknown      Html
# 4      dcc26@student.le.ac.uk  25/09/2023 09:00   Unknown  Unknown      Html
# ...                       ...               ...       ...      ...       ...
# 25495   ma880@leicester.ac.uk  25/09/2023 09:00   Unknown  Unknown      Html
# 25496    rnk8@leicester.ac.uk  25/09/2023 09:00   Unknown  Unknown      Html
# 25497   wiha1@leicester.ac.uk  25/09/2023 09:00   Unknown  Unknown      Html
# 25498         advice@le.ac.uk  25/09/2023 09:00   Unknown  Unknown      Html
# 25499     coursereps@le.ac.uk  25/09/2023 09:00   Unknown  Unknown      Html
#
# [25500 rows x 5 columns]

# %%
df_clickslaser.head()
# Out:
#    NumClicks                    Email EmailType Firstname Lastname
# 0          1  awtwta1@leicester.ac.uk      Html       NaN      NaN
# 1          1   yf111@student.le.ac.uk      Html       NaN      NaN
# 2          1   nj117@student.le.ac.uk      Html       NaN      NaN
# 3          1    zrb1@student.le.ac.uk      Html       NaN      NaN
# 4          1   cj196@student.le.ac.uk      Html       NaN      NaN

# %%
df_clickslaser.duplicated().sum()
# Out:
# 0

# %%
df_clickslaser.isnull().sum()
# Out:
# NumClicks      0
# Email          0
# EmailType      0
# Firstname    200
# Lastname     201
# dtype: int64

# %%
df_clickslaser["Firstname"] = df_clickslaser["Firstname"].fillna("Unknown")
df_clickslaser["Lastname"] = df_clickslaser["Lastname"].fillna("Unknown")
df_clickslaser
# Out:
#      NumClicks                    Email EmailType Firstname Lastname
# 0            1  awtwta1@leicester.ac.uk      Html   Unknown  Unknown
# 1            1   yf111@student.le.ac.uk      Html   Unknown  Unknown
# 2            1   nj117@student.le.ac.uk      Html   Unknown  Unknown
# 3            1    zrb1@student.le.ac.uk      Html   Unknown  Unknown
# 4            1   cj196@student.le.ac.uk      Html   Unknown  Unknown
# ..         ...                      ...       ...       ...      ...
# 197          1   sds42@student.le.ac.uk      Html   Unknown  Unknown
# 198          1   ssg17@student.le.ac.uk      Html   Unknown  Unknown
# 199          1  aa1402@student.le.ac.uk      Html   Unknown  Unknown
# 200          1   oa249@student.le.ac.uk      Html   Unknown  Unknown
# 201          1   aea22@student.le.ac.uk      Html   Unknown  Unknown
#
# [202 rows x 5 columns]

# %%
df_clicksmatriculation.head()
# Out:
#    NumClicks                    Email EmailType Firstname  Lastname
# 0          1    rds30@leicester.ac.uk      Html    Robert    Sulley
# 1          2   ral38@student.le.ac.uk      Html       NaN       NaN
# 2          1    kjw35@leicester.ac.uk      Html    Kirsty  Woodward
# 3          1     ej86@leicester.ac.uk      Html       NaN       NaN
# 4          1  js1020@student.le.ac.uk      Html       NaN       NaN

# %%
df_clicksmatriculation.duplicated().sum()
# Out:
# 0

# %%
df_clicksmatriculation.isnull().sum()
# Out:
# NumClicks      0
# Email          0
# EmailType      0
# Firstname    191
# Lastname     192
# dtype: int64

# %%
df_clicksmatriculation["Firstname"] = df_clickslaser["Firstname"].fillna("Unknown")
df_clicksmatriculation["Lastname"] = df_clickslaser["Lastname"].fillna("Unknown")
df_clicksmatriculation
# Out:
#      NumClicks                    Email EmailType Firstname Lastname
# 0            1    rds30@leicester.ac.uk      Html   Unknown  Unknown
# 1            2   ral38@student.le.ac.uk      Html   Unknown  Unknown
# 2            1    kjw35@leicester.ac.uk      Html   Unknown  Unknown
# 3            1     ej86@leicester.ac.uk      Html   Unknown  Unknown
# 4            1  js1020@student.le.ac.uk      Html   Unknown  Unknown
# ..         ...                      ...       ...       ...      ...
# 191          1   chs16@student.le.ac.uk      Html   Unknown  Unknown
# 192          1   faao2@student.le.ac.uk      Html   Unknown  Unknown
# 193          1   dlm22@student.le.ac.uk      Html   Unknown  Unknown
# 194          1   aiat1@student.le.ac.uk      Html   Unknown  Unknown
# 195          2              vc@le.ac.uk      Html   Unknown  Unknown
#
# [196 rows x 5 columns]

# %%
df_welcomeevent.head()
# Out:
#    NumClicks                    Email EmailType Firstname Lastname
# 0          1    rds30@leicester.ac.uk      Html    Robert   Sulley
# 1          1   jt438@student.le.ac.uk      Html       NaN      NaN
# 2          1   xz342@student.le.ac.uk      Html       NaN      NaN
# 3          1   jh658@student.le.ac.uk      Html       NaN      NaN
# 4          1  am1044@student.le.ac.uk      Html       NaN      NaN

# %%
df_welcomeevent.duplicated().sum()
# Out:
# 0

# %%
df_welcomeevent.isnull().sum()
# Out:
# NumClicks      0
# Email          0
# EmailType      0
# Firstname    718
# Lastname     721
# dtype: int64

# %%
df_welcomeevent["Firstname"] = df_welcomeevent["Firstname"].fillna("Unknown")
df_welcomeevent["Lastname"] = df_welcomeevent["Lastname"].fillna("Unknown")
df_welcomeevent
# Out:
#      NumClicks                    Email EmailType Firstname Lastname
# 0            1    rds30@leicester.ac.uk      Html    Robert   Sulley
# 1            1   jt438@student.le.ac.uk      Html   Unknown  Unknown
# 2            1   xz342@student.le.ac.uk      Html   Unknown  Unknown
# 3            1   jh658@student.le.ac.uk      Html   Unknown  Unknown
# 4            1  am1044@student.le.ac.uk      Html   Unknown  Unknown
# ..         ...                      ...       ...       ...      ...
# 724          1  am1433@student.le.ac.uk      Html   Unknown  Unknown
# 725          1  saaa13@student.le.ac.uk      Html   Unknown  Unknown
# 726          1  alsag1@student.le.ac.uk      Html   Unknown  Unknown
# 727          1   ccm23@student.le.ac.uk      Html   Unknown  Unknown
# 728          1   srsr1@student.le.ac.uk      Html   Unknown  Unknown
#
# [729 rows x 5 columns]

# %%
df_recepient_clickslink.head()
# Out:
#                      Email  Html  \
# 0    rds30@leicester.ac.uk  True
# 1    rds30@leicester.ac.uk  True
# 2  awtwta1@leicester.ac.uk  True
# 3     qc54@leicester.ac.uk  True
# 4   yf111@student.le.ac.uk  True
#
#                                                  Url       DateClicked  \
# 0              https://le.ac.uk/study/welcome/events  25/09/2023 09:13
# 1              https://le.ac.uk/study/welcome/events  25/09/2023 09:13
# 2    https://www.leicesterunion.com/ents/event/4978/  25/09/2023 09:01
# 3  https://le.ac.uk/study/wellbeing/support-services  25/09/2023 09:00
# 4    https://www.leicesterunion.com/ents/event/4978/  25/09/2023 18:35
#
#                                            UserAgent              IP  \
# 0  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...   81.107.88.126
# 1  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...   81.107.88.126
# 2  Mozilla/5.0 (iPhone; CPU iPhone OS 16_6_1 like...  89.197.196.222
# 3  Mozilla/5.0 (iPhone; CPU iPhone OS 16_1_2 like...    31.205.14.99
# 4  Mozilla/5.0 (iPhone; CPU iPhone OS 16_3_1 like...  223.104.253.65
#
#          Keyword  LinkGroups
# 0         events         NaN
# 1  matriculation         NaN
# 2          laser         NaN
# 3       Safezone         NaN
# 4          laser         NaN

# %%
df_recepient_clickslink.duplicated().sum()
# Out:
# 27

# %%
df_recepient_clickslink.drop_duplicates()
# Out:
#                         Email  Html  \
# 0       rds30@leicester.ac.uk  True
# 1       rds30@leicester.ac.uk  True
# 2     awtwta1@leicester.ac.uk  True
# 3        qc54@leicester.ac.uk  True
# 4      yf111@student.le.ac.uk  True
# ...                       ...   ...
# 1668   aiat1@student.le.ac.uk  True
# 1669   srsr1@student.le.ac.uk  True
# 1670              vc@le.ac.uk  True
# 1671              vc@le.ac.uk  True
# 1672   mjc100@leicester.ac.uk  True
#
#                                                     Url       DateClicked  \
# 0                 https://le.ac.uk/study/welcome/events  25/09/2023 09:13
# 1                 https://le.ac.uk/study/welcome/events  25/09/2023 09:13
# 2       https://www.leicesterunion.com/ents/event/4978/  25/09/2023 09:01
# 3     https://le.ac.uk/study/wellbeing/support-services  25/09/2023 09:00
# 4       https://www.leicesterunion.com/ents/event/4978/  25/09/2023 18:35
# ...                                                 ...               ...
# 1668              https://le.ac.uk/study/welcome/events  25/09/2023 18:55
# 1669              https://le.ac.uk/study/welcome/events  25/09/2023 12:14
# 1670              https://le.ac.uk/study/welcome/events  25/09/2023 09:01
# 1671              https://le.ac.uk/study/welcome/events  25/09/2023 09:00
# 1672  https://www.eventbrite.com/e/city-tours-leices...  25/09/2023 10:41
#
#                                               UserAgent              IP  \
# 0     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...   81.107.88.126
# 1     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...   81.107.88.126
# 2     Mozilla/5.0 (iPhone; CPU iPhone OS 16_6_1 like...  89.197.196.222
# 3     Mozilla/5.0 (iPhone; CPU iPhone OS 16_1_2 like...    31.205.14.99
# 4     Mozilla/5.0 (iPhone; CPU iPhone OS 16_3_1 like...  223.104.253.65
# ...                                                 ...             ...
# 1668  Mozilla/5.0 (iPhone; CPU iPhone OS 16_4 like M...    5.151.89.195
# 1669  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...  85.255.235.175
# 1670  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   143.210.96.45
# 1671  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   143.210.96.45
# 1672  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...    89.37.175.42
#
#                   Keyword  LinkGroups
# 0                  events         NaN
# 1           matriculation         NaN
# 2                   laser         NaN
# 3                Safezone         NaN
# 4                   laser         NaN
# ...                   ...         ...
# 1668        matriculation         NaN
# 1669               events         NaN
# 1670        matriculation         NaN
# 1671        matriculation         NaN
# 1672  Leicester uncovered         NaN
#
# [1646 rows x 8 columns]

# %%
df_recepient_clickslink.isnull().sum()
# Out:
# Email             0
# Html              0
# Url               0
# DateClicked       0
# UserAgent         0
# IP                0
# Keyword          12
# LinkGroups     1673
# dtype: int64

# %%
df_recepient_clickslink["Keyword"] = df_recepient_clickslink["Keyword"].fillna("Unknown")
df_recepient_clickslink["LinkGroups"] = df_recepient_clickslink["LinkGroups"].fillna("Unknown")
df_recepient_clickslink
# Out:
#                         Email  Html  \
# 0       rds30@leicester.ac.uk  True
# 1       rds30@leicester.ac.uk  True
# 2     awtwta1@leicester.ac.uk  True
# 3        qc54@leicester.ac.uk  True
# 4      yf111@student.le.ac.uk  True
# ...                       ...   ...
# 1668   aiat1@student.le.ac.uk  True
# 1669   srsr1@student.le.ac.uk  True
# 1670              vc@le.ac.uk  True
# 1671              vc@le.ac.uk  True
# 1672   mjc100@leicester.ac.uk  True
#
#                                                     Url       DateClicked  \
# 0                 https://le.ac.uk/study/welcome/events  25/09/2023 09:13
# 1                 https://le.ac.uk/study/welcome/events  25/09/2023 09:13
# 2       https://www.leicesterunion.com/ents/event/4978/  25/09/2023 09:01
# 3     https://le.ac.uk/study/wellbeing/support-services  25/09/2023 09:00
# 4       https://www.leicesterunion.com/ents/event/4978/  25/09/2023 18:35
# ...                                                 ...               ...
# 1668              https://le.ac.uk/study/welcome/events  25/09/2023 18:55
# 1669              https://le.ac.uk/study/welcome/events  25/09/2023 12:14
# 1670              https://le.ac.uk/study/welcome/events  25/09/2023 09:01
# 1671              https://le.ac.uk/study/welcome/events  25/09/2023 09:00
# 1672  https://www.eventbrite.com/e/city-tours-leices...  25/09/2023 10:41
#
#                                               UserAgent              IP  \
# 0     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...   81.107.88.126
# 1     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...   81.107.88.126
# 2     Mozilla/5.0 (iPhone; CPU iPhone OS 16_6_1 like...  89.197.196.222
# 3     Mozilla/5.0 (iPhone; CPU iPhone OS 16_1_2 like...    31.205.14.99
# 4     Mozilla/5.0 (iPhone; CPU iPhone OS 16_3_1 like...  223.104.253.65
# ...                                                 ...             ...
# 1668  Mozilla/5.0 (iPhone; CPU iPhone OS 16_4 like M...    5.151.89.195
# 1669  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...  85.255.235.175
# 1670  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   143.210.96.45
# 1671  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...   143.210.96.45
# 1672  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...    89.37.175.42
#
#                   Keyword LinkGroups
# 0                  events    Unknown
# 1           matriculation    Unknown
# 2                   laser    Unknown
# 3                Safezone    Unknown
# 4                   laser    Unknown
# ...                   ...        ...
# 1668        matriculation    Unknown
# 1669               events    Unknown
# 1670        matriculation    Unknown
# 1671        matriculation    Unknown
# 1672  Leicester uncovered    Unknown
#
# [1673 rows x 8 columns]

# %%
def total_opens():
    total_opens = df_emailopened["NumOpens"].sum()
    print("Total number of NumOpens: ", total_opens)



total_opens()
# Out:
# Total number of NumOpens:  28672

# %%
average_opens = df_emailopened["NumOpens"].mean()
df_emailopened["AverageNumOpens"] = average_opens

print("Average number of NumOpens:", average_opens)
# Out:
# Average number of NumOpens: 2.1965831609591664

# %%
minimum_opens = df_emailopened["NumOpens"].min()
df_emailopened["MinimumOpens"] = minimum_opens
print("Minimum number of NumOpens: ", minimum_opens)
# Out:
# Minimum number of NumOpens:  1

# %%
maximum_opens = df_emailopened["NumOpens"].max()
print("Maximum number of NumOpens: ", maximum_opens)
# Out:
# Maximum number of NumOpens:  30

# %%
df_emailopened["DateOpened"] = pd.to_datetime(df_emailopened["DateOpened"], format="%d/%m/%Y %H:%M") #convert string to datetime

# %%
df_emailopened["DateOpenedLast"] = pd.to_datetime(df_emailopened["DateOpenedLast"], format="%d/%m/%Y %H:%M") #convert string to datetime

# %%
df_emailopened["EngagementSpan"] = df_emailopened["DateOpenedLast"] - df_emailopened["DateOpened"]
df_emailopened.head(10)
# Out:
#    NumOpens                   Email EmailType          DateOpened  \
# 0         1   ucn1@student.le.ac.uk      Html 2023-10-02 16:34:00
# 1         1  jg562@student.le.ac.uk      Html 2023-10-25 17:09:00
# 2         1   vdg2@student.le.ac.uk      Html 2023-09-26 20:58:00
# 3         1  dcc26@student.le.ac.uk      Html 2023-09-25 12:31:00
# 4         1  arc39@student.le.ac.uk      Html 2023-11-08 17:31:00
# 5         1  hc365@student.le.ac.uk      Html 2023-09-25 10:49:00
# 6         1   wlr1@student.le.ac.uk      Html 2023-09-25 18:05:00
# 7         2   zgp2@student.le.ac.uk      Html 2023-09-25 12:27:00
# 8         3  shia1@student.le.ac.uk      Html 2023-09-25 09:06:00
# 9         2  jarf1@student.le.ac.uk      Html 2023-09-25 12:12:00
#
#        DateOpenedLast  AverageNumOpens  MinimumOpens  EngagementSpan
# 0 2023-10-02 16:34:00         2.196583             1 0 days 00:00:00
# 1 2023-10-25 17:09:00         2.196583             1 0 days 00:00:00
# 2 2023-09-26 20:58:00         2.196583             1 0 days 00:00:00
# 3 2023-09-25 12:31:00         2.196583             1 0 days 00:00:00
# 4 2023-11-08 17:31:00         2.196583             1 0 days 00:00:00
# 5 2023-09-25 10:49:00         2.196583             1 0 days 00:00:00
# 6 2023-09-25 18:05:00         2.196583             1 0 days 00:00:00
# 7 2023-09-25 12:27:00         2.196583             1 0 days 00:00:00
# 8 2023-09-28 12:48:00         2.196583             1 3 days 03:42:00
# 9 2023-09-25 12:12:00         2.196583             1 0 days 00:00:00

# %%
df_emailopened["EngagementHours"] = df_emailopened["EngagementSpan"].dt.total_seconds() / 3600
df_emailopened
# Out:
#        NumOpens                   Email EmailType          DateOpened  \
# 0             1   ucn1@student.le.ac.uk      Html 2023-10-02 16:34:00
# 1             1  jg562@student.le.ac.uk      Html 2023-10-25 17:09:00
# 2             1   vdg2@student.le.ac.uk      Html 2023-09-26 20:58:00
# 3             1  dcc26@student.le.ac.uk      Html 2023-09-25 12:31:00
# 4             1  arc39@student.le.ac.uk      Html 2023-11-08 17:31:00
# ...         ...                     ...       ...                 ...
# 13048         3   okf8@student.le.ac.uk      Html 2023-09-25 09:55:00
# 13049         7   fama4@leicester.ac.uk      Html 2023-09-25 09:19:00
# 13050         1   wiha1@leicester.ac.uk      Html 2023-09-26 03:22:00
# 13051         2         advice@le.ac.uk      Html 2023-09-25 09:01:00
# 13052         1     coursereps@le.ac.uk      Html 2023-09-25 11:07:00
#
#            DateOpenedLast  AverageNumOpens  MinimumOpens  EngagementSpan  \
# 0     2023-10-02 16:34:00         2.196583             1 0 days 00:00:00
# 1     2023-10-25 17:09:00         2.196583             1 0 days 00:00:00
# 2     2023-09-26 20:58:00         2.196583             1 0 days 00:00:00
# 3     2023-09-25 12:31:00         2.196583             1 0 days 00:00:00
# 4     2023-11-08 17:31:00         2.196583             1 0 days 00:00:00
# ...                   ...              ...           ...             ...
# 13048 2023-09-25 11:36:00         2.196583             1 0 days 01:41:00
# 13049 2023-09-25 09:49:00         2.196583             1 0 days 00:30:00
# 13050 2023-09-26 03:22:00         2.196583             1 0 days 00:00:00
# 13051 2023-09-25 09:26:00         2.196583             1 0 days 00:25:00
# 13052 2023-09-25 11:07:00         2.196583             1 0 days 00:00:00
#
#        EngagementHours
# 0             0.000000
# 1             0.000000
# 2             0.000000
# 3             0.000000
# 4             0.000000
# ...                ...
# 13048         1.683333
# 13049         0.500000
# 13050         0.000000
# 13051         0.416667
# 13052         0.000000
#
# [13053 rows x 9 columns]

# %%
def numopen_level_classification(opens): #categorising open levels into different categories
    if opens <= 1:
        return 'Low'
    elif opens <= 4:
        return 'Medium'
    else:
        return 'High'

# %%
df_emailopened["Openlevel"] = df_emailopened["NumOpens"].apply(numopen_level_classification)
df_emailopened
# Out:
#        NumOpens                   Email EmailType          DateOpened  \
# 0             1   ucn1@student.le.ac.uk      Html 2023-10-02 16:34:00
# 1             1  jg562@student.le.ac.uk      Html 2023-10-25 17:09:00
# 2             1   vdg2@student.le.ac.uk      Html 2023-09-26 20:58:00
# 3             1  dcc26@student.le.ac.uk      Html 2023-09-25 12:31:00
# 4             1  arc39@student.le.ac.uk      Html 2023-11-08 17:31:00
# ...         ...                     ...       ...                 ...
# 13048         3   okf8@student.le.ac.uk      Html 2023-09-25 09:55:00
# 13049         7   fama4@leicester.ac.uk      Html 2023-09-25 09:19:00
# 13050         1   wiha1@leicester.ac.uk      Html 2023-09-26 03:22:00
# 13051         2         advice@le.ac.uk      Html 2023-09-25 09:01:00
# 13052         1     coursereps@le.ac.uk      Html 2023-09-25 11:07:00
#
#            DateOpenedLast  AverageNumOpens  MinimumOpens  EngagementSpan  \
# 0     2023-10-02 16:34:00         2.196583             1 0 days 00:00:00
# 1     2023-10-25 17:09:00         2.196583             1 0 days 00:00:00
# 2     2023-09-26 20:58:00         2.196583             1 0 days 00:00:00
# 3     2023-09-25 12:31:00         2.196583             1 0 days 00:00:00
# 4     2023-11-08 17:31:00         2.196583             1 0 days 00:00:00
# ...                   ...              ...           ...             ...
# 13048 2023-09-25 11:36:00         2.196583             1 0 days 01:41:00
# 13049 2023-09-25 09:49:00         2.196583             1 0 days 00:30:00
# 13050 2023-09-26 03:22:00         2.196583             1 0 days 00:00:00
# 13051 2023-09-25 09:26:00         2.196583             1 0 days 00:25:00
# 13052 2023-09-25 11:07:00         2.196583             1 0 days 00:00:00
#
#        EngagementHours Openlevel
# 0             0.000000       Low
# 1             0.000000       Low
# 2             0.000000       Low
# 3             0.000000       Low
# 4             0.000000       Low
# ...                ...       ...
# 13048         1.683333    Medium
# 13049         0.500000      High
# 13050         0.000000       Low
# 13051         0.416667    Medium
# 13052         0.000000       Low
#
# [13053 rows x 10 columns]

# %%
df_emailopened["Openlevel"].value_counts().plot(kind='bar', title='Email Engagement Levels')
plt.ylabel("Number of People")
plt.show()
df_emailopened["Openlevel"].value_counts()
#high levels of medium open level
#low levels of high open level
# Out:
# Medium    7759
# Low       4479
# High       815
# Name: Openlevel, dtype: int64

# %%
df_emailopened.groupby("EmailType")["AverageNumOpens"].mean().plot(kind="bar", title="Average Opens per Email Type")
plt.ylabel("Average Opens")
plt.show()
df_emailopened.groupby("EmailType")["AverageNumOpens"].value_counts()
# Out:
# EmailType  AverageNumOpens
# Html       2.196583           13053
# Name: AverageNumOpens, dtype: int64

# %%
# Bin the data into 10 bins using pd.cut
bins = pd.cut(df_emailopened['EngagementHours'], bins=10).value_counts().sort_index()
print(bins)

df_emailopened['EngagementHours'].plot(kind='hist', bins=10, title='Distribution of Engagement Hours')
plt.show()

#timeframe of engagement hours (timeframe email is opened), frequency == amount of people
# Out:
# (-15.292, 1529.203]       12726
# (1529.203, 3058.407]        119
# (3058.407, 4587.61]          69
# (4587.61, 6116.813]          33
# (6116.813, 7646.017]         25
# (7646.017, 9175.22]          46
# (9175.22, 10704.423]         10
# (10704.423, 12233.627]       11
# (12233.627, 13762.83]        10
# (13762.83, 15292.033]         4
# Name: EngagementHours, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(
    x='Openlevel',
    y='EngagementHours',
    data=df_emailopened,
    boxprops=dict(facecolor='white', edgecolor='black'),
    whiskerprops=dict(color='black'),
    capprops=dict(color='black'),
    medianprops=dict(color='black'),
    flierprops=dict(marker='o', color='black', alpha=0.3, markersize=3),
    showfliers=True
)

plt.yscale('log')  #log scale to handle skewed data
plt.title('Engagement Span by Open Level (Log Scale)')
plt.grid(True, which="both", axis='y', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()


sns.boxplot(x='Openlevel', y='EngagementHours', data=df_emailopened).set_title('Engagement Span by Open Level')

df_emailopened.groupby("Openlevel")["EngagementHours"].std()
# Out:
# Openlevel
# High      1904.520035
# Low          0.000000
# Medium    1053.377324
# Name: EngagementHours, dtype: float64

# %%
##most and least clicked links

def total_clicks():
    total_clickswelcomeevents = df_welcomeevent["NumClicks"].sum()
    print("Total number of NumClicks for https://le.ac.uk/study/welcome/events : ", total_clickswelcomeevents)
    
    total_clicksmatriculation = df_clicksmatriculation["NumClicks"].sum()
    print("Total number of NumClicks for https://le.ac.uk/study/welcome/events : ", total_clicksmatriculation)
    

    total_clickslaser = df_clickslaser["NumClicks"].sum()
    print("Total number of NumClicks for https://www.leicesterunion.com/ents/event/4978/: ", total_clickslaser)
    
    
    
    
    
    



total_clicks()
# Out:
# Total number of NumClicks for https://le.ac.uk/study/welcome/events :  864
# Total number of NumClicks for https://le.ac.uk/study/welcome/events :  231
# Total number of NumClicks for https://www.leicesterunion.com/ents/event/4978/:  223
