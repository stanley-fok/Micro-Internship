# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
from datetime import datetime

# %%
df_emailopened = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September262023/Tuesday-26-September-EmailOpened.csv")

df_emailsends = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September262023/Tuesday-26-September-EmailSends.csv")

df_clicksdogs = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September262023/Tuesday-26-September-Link-clicksdogs.csv")

df_clickssportsfairoadby = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September262023/Tuesday-26-September-Link-clickssports fair oadby.csv")

df_clicksvintagefair = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September262023/Tuesday-26-September-Link-clicksvintage fair.csv")

df_recepient_clickslink = pd.read_csv("C:/Users/fokst/OneDrive/Desktop/Microinternship/Week2_Microinternship/September262023/Tuesday-26-September-Recipient-clickslink.csv")

# %%
df_emailopened.head()
# Out:
#    NumOpens                   Email EmailType        DateOpened  \
# 0         1   ucn1@student.le.ac.uk      Html  02/10/2023 16:34
# 1         2  jlpc1@student.le.ac.uk      Html  01/10/2023 17:16
# 2         1  jg562@student.le.ac.uk      Html  25/10/2023 17:09
# 3         1   vdg2@student.le.ac.uk      Html  26/09/2023 20:58
# 4         1  dcc26@student.le.ac.uk      Html  26/09/2023 09:07
#
#      DateOpenedLast
# 0  02/10/2023 16:34
# 1  01/10/2023 17:16
# 2  25/10/2023 17:09
# 3  26/09/2023 20:58
# 4  26/09/2023 09:07

# %%
df_emailsends.value_counts()
# Out:
# Email                    DateSent          Firstname  Lastname  EmailType
# a1033@student.le.ac.uk   26/09/2023 09:01  Unknown    Unknown   Html         1
# ns599@student.le.ac.uk   26/09/2023 09:01  Unknown    Unknown   Html         1
# ns611@student.le.ac.uk   26/09/2023 09:01  Unknown    Unknown   Html         1
# ns610@student.le.ac.uk   26/09/2023 09:01  Unknown    Unknown   Html         1
# ns608@student.le.ac.uk   26/09/2023 09:01  Unknown    Unknown   Html         1
#                                                                             ..
# hee6@student.le.ac.uk    26/09/2023 09:00  Unknown    Unknown   Html         1
# hee5@student.le.ac.uk    26/09/2023 09:01  Unknown    Unknown   Html         1
# hedce1@student.le.ac.uk  26/09/2023 09:01  Unknown    Unknown   Html         1
# heda1@student.le.ac.uk   26/09/2023 09:01  Unknown    Unknown   Html         1
# zz300@student.le.ac.uk   26/09/2023 09:00  Unknown    Unknown   Html         1
# Length: 25699, dtype: int64

# %%
df_emailopened.duplicated().sum()
# Out:
# 0

# %%
df_emailopened.isnull().sum()
# Out:
# NumOpens          0
# Email             0
# EmailType         0
# DateOpened        0
# DateOpenedLast    0
# dtype: int64

# %%
df_emailsends.head()
# Out:
#                     Email          DateSent Firstname Lastname EmailType
# 0   ucn1@student.le.ac.uk  26/09/2023 09:00       NaN      NaN      Html
# 1  jlpc1@student.le.ac.uk  26/09/2023 09:00       NaN      NaN      Html
# 2  jg562@student.le.ac.uk  26/09/2023 09:00       NaN      NaN      Html
# 3   vdg2@student.le.ac.uk  26/09/2023 09:00       NaN      NaN      Html
# 4  dcc26@student.le.ac.uk  26/09/2023 09:00       NaN      NaN      Html

# %%
df_emailsends.duplicated().sum()
# Out:
# 0

# %%
df_emailsends.isnull().sum()
# Out:
# Email            0
# DateSent         0
# Firstname    24696
# Lastname     24791
# EmailType        0
# dtype: int64

# %%
df_emailsends['Firstname'] = df_emailsends['Firstname'].fillna('Unknown')
df_emailsends['Lastname'] = df_emailsends['Lastname'].fillna('Unknown')
df_emailsends
# Out:
#                         Email          DateSent Firstname Lastname EmailType
# 0       ucn1@student.le.ac.uk  26/09/2023 09:00   Unknown  Unknown      Html
# 1      jlpc1@student.le.ac.uk  26/09/2023 09:00   Unknown  Unknown      Html
# 2      jg562@student.le.ac.uk  26/09/2023 09:00   Unknown  Unknown      Html
# 3       vdg2@student.le.ac.uk  26/09/2023 09:00   Unknown  Unknown      Html
# 4      dcc26@student.le.ac.uk  26/09/2023 09:00   Unknown  Unknown      Html
# ...                       ...               ...       ...      ...       ...
# 25694   ma880@leicester.ac.uk  26/09/2023 09:01   Unknown  Unknown      Html
# 25695    rnk8@leicester.ac.uk  26/09/2023 09:01   Unknown  Unknown      Html
# 25696   wiha1@leicester.ac.uk  26/09/2023 09:01   Unknown  Unknown      Html
# 25697         advice@le.ac.uk  26/09/2023 09:01   Unknown  Unknown      Html
# 25698     coursereps@le.ac.uk  26/09/2023 09:01   Unknown  Unknown      Html
#
# [25699 rows x 5 columns]

# %%
df_clicksdogs.head()
# Out:
#    NumClicks  NumClicks.1                   Email EmailType Firstname Lastname
# 0          1            1  cb687@student.le.ac.uk      Html       NaN      NaN
# 1          1            1  slc83@student.le.ac.uk      Html       NaN      NaN
# 2          1            1   imp7@student.le.ac.uk      Html       NaN      NaN
# 3          1            1   lv50@student.le.ac.uk      Html       NaN      NaN
# 4          1            1   ffc2@student.le.ac.uk      Html       NaN      NaN

# %%
df_clicksdogs.duplicated().sum()
# Out:
# 0

# %%
df_clicksdogs.isnull().sum()
# Out:
# NumClicks        0
# NumClicks.1      0
# Email            0
# EmailType        0
# Firstname      196
# Lastname       200
# dtype: int64

# %%
df_clicksdogs["Firstname"] = df_clicksdogs["Firstname"].fillna("Unknown")
df_clicksdogs["Lastname"] = df_clicksdogs["Lastname"].fillna("Unknown")
df_clicksdogs
# Out:
#      NumClicks  NumClicks.1                    Email EmailType Firstname  \
# 0            1            1   cb687@student.le.ac.uk      Html   Unknown
# 1            1            1   slc83@student.le.ac.uk      Html   Unknown
# 2            1            1    imp7@student.le.ac.uk      Html   Unknown
# 3            1            1    lv50@student.le.ac.uk      Html   Unknown
# 4            1            1    ffc2@student.le.ac.uk      Html   Unknown
# ..         ...          ...                      ...       ...       ...
# 199          1            1   lk239@student.le.ac.uk      Html   Unknown
# 200          1            1  ms1271@student.le.ac.uk      Html   Unknown
# 201          1            1   gh215@student.le.ac.uk      Html   Unknown
# 202          1            1   am1412@leicester.ac.uk      Html   Unknown
# 203          1            1   at602@student.le.ac.uk      Html   Unknown
#
#     Lastname
# 0    Unknown
# 1    Unknown
# 2    Unknown
# 3    Unknown
# 4    Unknown
# ..       ...
# 199  Unknown
# 200  Unknown
# 201  Unknown
# 202  Unknown
# 203  Unknown
#
# [204 rows x 6 columns]

# %%
df_clickssportsfairoadby.head()
# Out:
#    NumClicks  NumClicks.1                    Email EmailType Firstname  \
# 0          1            1    lv50@student.le.ac.uk      Html       NaN
# 1          2            2   jp545@student.le.ac.uk      Html       NaN
# 2          1            1  js1083@student.le.ac.uk      Html       NaN
# 3          1            1   rg293@student.le.ac.uk      Html       NaN
# 4          2            2  ms1150@student.le.ac.uk      Html       NaN
#
#   Lastname
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
df_clickssportsfairoadby.duplicated().sum()
# Out:
# 0

# %%
df_clickssportsfairoadby.isnull().sum()
# Out:
# NumClicks        0
# NumClicks.1      0
# Email            0
# EmailType        0
# Firstname      245
# Lastname       245
# dtype: int64

# %%
df_clickssportsfairoadby["Firstname"] = df_clickssportsfairoadby["Firstname"].fillna("Unknown")
df_clickssportsfairoadby["Lastname"] = df_clickssportsfairoadby["Lastname"].fillna("Unknown")
df_clickssportsfairoadby
# Out:
#      NumClicks  NumClicks.1                    Email EmailType Firstname  \
# 0            1            1    lv50@student.le.ac.uk      Html   Unknown
# 1            2            2   jp545@student.le.ac.uk      Html   Unknown
# 2            1            1  js1083@student.le.ac.uk      Html   Unknown
# 3            1            1   rg293@student.le.ac.uk      Html   Unknown
# 4            2            2  ms1150@student.le.ac.uk      Html   Unknown
# ..         ...          ...                      ...       ...       ...
# 241          1            1   ya115@student.le.ac.uk      Html   Unknown
# 242          2            2    aw520@leicester.ac.uk      Html   Unknown
# 243          1            1  as1483@student.le.ac.uk      Html   Unknown
# 244          1            1    jb951@leicester.ac.uk      Html   Unknown
# 245          2            2   gw189@student.le.ac.uk      Html   Unknown
#
#     Lastname
# 0    Unknown
# 1    Unknown
# 2    Unknown
# 3    Unknown
# 4    Unknown
# ..       ...
# 241  Unknown
# 242  Unknown
# 243  Unknown
# 244  Unknown
# 245  Unknown
#
# [246 rows x 6 columns]

# %%
df_clicksvintagefair.head()
# Out:
#    NumClicks  NumClicks.1                   Email EmailType Firstname Lastname
# 0          1            1  cz173@student.le.ac.uk      Html       NaN      NaN
# 1          1            1   ler20@leicester.ac.uk      Html   Loo Loo     Rose
# 2          1            1  va101@student.le.ac.uk      Html       NaN      NaN
# 3          1            1   imp7@student.le.ac.uk      Html       NaN      NaN
# 4          1            1  hb320@student.le.ac.uk      Html       NaN      NaN

# %%
df_clicksvintagefair.duplicated().sum()
# Out:
# 0

# %%
df_clicksvintagefair.isnull().sum()
# Out:
# NumClicks        0
# NumClicks.1      0
# Email            0
# EmailType        0
# Firstname      350
# Lastname       350
# dtype: int64

# %%
df_clicksvintagefair["Firstname"] = df_clicksvintagefair["Firstname"].fillna("Unknown")
df_clicksvintagefair["Lastname"] = df_clicksvintagefair["Lastname"].fillna("Unknown")
df_clicksvintagefair
# Out:
#      NumClicks  NumClicks.1                    Email EmailType Firstname  \
# 0            1            1   cz173@student.le.ac.uk      Html   Unknown
# 1            1            1    ler20@leicester.ac.uk      Html   Loo Loo
# 2            1            1   va101@student.le.ac.uk      Html   Unknown
# 3            1            1    imp7@student.le.ac.uk      Html   Unknown
# 4            1            1   hb320@student.le.ac.uk      Html   Unknown
# ..         ...          ...                      ...       ...       ...
# 351          4            4   skgj1@student.le.ac.uk      Html   Unknown
# 352          1            1  ma1016@student.le.ac.uk      Html   Unknown
# 353          1            1   sy234@student.le.ac.uk      Html   Unknown
# 354          1            1  alsag1@student.le.ac.uk      Html   Unknown
# 355          3            3            hso1@le.ac.uk      Html       Hen
#
#      Lastname
# 0     Unknown
# 1        Rose
# 2     Unknown
# 3     Unknown
# 4     Unknown
# ..        ...
# 351   Unknown
# 352   Unknown
# 353   Unknown
# 354   Unknown
# 355  O'Connor
#
# [356 rows x 6 columns]

# %%
df_recepient_clickslink.head()
# Out:
#                     Email  Html  \
# 0  rmaw3@student.le.ac.uk  True
# 1  cb687@student.le.ac.uk  True
# 2  slc83@student.le.ac.uk  True
# 3  cz173@student.le.ac.uk  True
# 4   ler20@leicester.ac.uk  True
#
#                                                 Url       DateClicked  \
# 0      https://reslife.le.ac.uk/crafts--cake_189719  26/09/2023 15:45
# 1   https://www.leicesterunion.com/ents/event/4981/  26/09/2023 13:02
# 2   https://www.leicesterunion.com/ents/event/4981/  26/09/2023 09:17
# 3  https://www.leicesterunion.com/events/6013/4963/  26/09/2023 09:08
# 4  https://www.leicesterunion.com/events/6013/4963/  26/09/2023 09:28
#
#                                            UserAgent              IP  \
# 0  Mozilla/5.0 (iPhone; CPU iPhone OS 16_6_1 like...  85.193.152.146
# 1  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  143.210.52.155
# 2  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...   143.210.52.94
# 3  Mozilla/5.0 (iPhone; CPU iPhone OS 16_6_1 like...   82.30.120.172
# 4  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  143.210.241.41
#
#           Keyword  LinkGroups
# 0  craft and cake         NaN
# 1            dogs         NaN
# 2            dogs         NaN
# 3    vintage fair         NaN
# 4    vintage fair         NaN

# %%
df_recepient_clickslink.duplicated().sum()
# Out:
# 26

# %%
df_recepient_clickslink.drop_duplicates()
# Out:
#                        Email  Html  \
# 0     rmaw3@student.le.ac.uk  True
# 1     cb687@student.le.ac.uk  True
# 2     slc83@student.le.ac.uk  True
# 3     cz173@student.le.ac.uk  True
# 4      ler20@leicester.ac.uk  True
# ...                      ...   ...
# 1348  smza2@student.le.ac.uk  True
# 1349           hso1@le.ac.uk  True
# 1350           hso1@le.ac.uk  True
# 1351           hso1@le.ac.uk  True
# 1352   tjb47@leicester.ac.uk  True
#
#                                                    Url       DateClicked  \
# 0         https://reslife.le.ac.uk/crafts--cake_189719  26/09/2023 15:45
# 1      https://www.leicesterunion.com/ents/event/4981/  26/09/2023 13:02
# 2      https://www.leicesterunion.com/ents/event/4981/  26/09/2023 09:17
# 3     https://www.leicesterunion.com/events/6013/4963/  26/09/2023 09:08
# 4     https://www.leicesterunion.com/events/6013/4963/  26/09/2023 09:28
# ...                                                ...               ...
# 1348             https://le.ac.uk/study/welcome/events  27/09/2023 10:23
# 1349  https://www.leicesterunion.com/events/6013/4963/  26/09/2023 09:15
# 1350  https://www.leicesterunion.com/events/6013/4963/  26/09/2023 09:14
# 1351  https://www.leicesterunion.com/events/6013/4963/  26/09/2023 09:15
# 1352             https://le.ac.uk/study/welcome/events  26/09/2023 09:02
#
#                                               UserAgent              IP  \
# 0     Mozilla/5.0 (iPhone; CPU iPhone OS 16_6_1 like...  85.193.152.146
# 1     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  143.210.52.155
# 2     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...   143.210.52.94
# 3     Mozilla/5.0 (iPhone; CPU iPhone OS 16_6_1 like...   82.30.120.172
# 4     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  143.210.241.41
# ...                                                 ...             ...
# 1348  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...   5.151.227.243
# 1349  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...    40.94.96.126
# 1350  Mozilla/5.0 (iPhone; CPU iPhone OS 16_6_1 like...   82.25.177.118
# 1351  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...     40.94.96.90
# 1352  Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:1...   63.155.62.166
#
#                             Keyword  LinkGroups
# 0                    craft and cake         NaN
# 1                              dogs         NaN
# 2                              dogs         NaN
# 3                      vintage fair         NaN
# 4                      vintage fair         NaN
# ...                             ...         ...
# 1348  Support and volunteering fair         NaN
# 1349                   vintage fair         NaN
# 1350                   vintage fair         NaN
# 1351                   vintage fair         NaN
# 1352                  matriculation         NaN
#
# [1327 rows x 8 columns]

# %%
df_recepient_clickslink.isnull().sum()
# Out:
# Email             0
# Html              0
# Url               0
# DateClicked       0
# UserAgent         0
# IP                0
# Keyword          39
# LinkGroups     1353
# dtype: int64

# %%
df_recepient_clickslink["Keyword"] = df_recepient_clickslink["Keyword"].fillna("Unknown")
df_recepient_clickslink["LinkGroups"] = df_recepient_clickslink["LinkGroups"].fillna("Unknown")
df_recepient_clickslink
# Out:
#                        Email  Html  \
# 0     rmaw3@student.le.ac.uk  True
# 1     cb687@student.le.ac.uk  True
# 2     slc83@student.le.ac.uk  True
# 3     cz173@student.le.ac.uk  True
# 4      ler20@leicester.ac.uk  True
# ...                      ...   ...
# 1348  smza2@student.le.ac.uk  True
# 1349           hso1@le.ac.uk  True
# 1350           hso1@le.ac.uk  True
# 1351           hso1@le.ac.uk  True
# 1352   tjb47@leicester.ac.uk  True
#
#                                                    Url       DateClicked  \
# 0         https://reslife.le.ac.uk/crafts--cake_189719  26/09/2023 15:45
# 1      https://www.leicesterunion.com/ents/event/4981/  26/09/2023 13:02
# 2      https://www.leicesterunion.com/ents/event/4981/  26/09/2023 09:17
# 3     https://www.leicesterunion.com/events/6013/4963/  26/09/2023 09:08
# 4     https://www.leicesterunion.com/events/6013/4963/  26/09/2023 09:28
# ...                                                ...               ...
# 1348             https://le.ac.uk/study/welcome/events  27/09/2023 10:23
# 1349  https://www.leicesterunion.com/events/6013/4963/  26/09/2023 09:15
# 1350  https://www.leicesterunion.com/events/6013/4963/  26/09/2023 09:14
# 1351  https://www.leicesterunion.com/events/6013/4963/  26/09/2023 09:15
# 1352             https://le.ac.uk/study/welcome/events  26/09/2023 09:02
#
#                                               UserAgent              IP  \
# 0     Mozilla/5.0 (iPhone; CPU iPhone OS 16_6_1 like...  85.193.152.146
# 1     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  143.210.52.155
# 2     Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_7...   143.210.52.94
# 3     Mozilla/5.0 (iPhone; CPU iPhone OS 16_6_1 like...   82.30.120.172
# 4     Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...  143.210.241.41
# ...                                                 ...             ...
# 1348  Mozilla/5.0 (Linux; Android 10; K) AppleWebKit...   5.151.227.243
# 1349  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...    40.94.96.126
# 1350  Mozilla/5.0 (iPhone; CPU iPhone OS 16_6_1 like...   82.25.177.118
# 1351  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...     40.94.96.90
# 1352  Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:1...   63.155.62.166
#
#                             Keyword LinkGroups
# 0                    craft and cake    Unknown
# 1                              dogs    Unknown
# 2                              dogs    Unknown
# 3                      vintage fair    Unknown
# 4                      vintage fair    Unknown
# ...                             ...        ...
# 1348  Support and volunteering fair    Unknown
# 1349                   vintage fair    Unknown
# 1350                   vintage fair    Unknown
# 1351                   vintage fair    Unknown
# 1352                  matriculation    Unknown
#
# [1353 rows x 8 columns]

# %%
def total_opens():
    total_opens = df_emailopened["NumOpens"].sum()
    print("Total number of NumOpens: ", total_opens)



total_opens()
# Out:
# Total number of NumOpens:  26710

# %%
average_opens = df_emailopened["NumOpens"].mean()
df_emailopened["AverageNumOpens"] = average_opens

print("Average number of NumOpens:", average_opens)
# Out:
# Average number of NumOpens: 2.1294746073507134

# %%
minimum_opens = df_emailopened["NumOpens"].min()
df_emailopened["MinimumOpens"] = minimum_opens
print("Minimum number of NumOpens: ", minimum_opens)
# Out:
# Minimum number of NumOpens:  1

# %%
maximum_opens = df_emailopened["NumOpens"].max()
df_emailopened["MaximumOpens"] = maximum_opens
print("Maximum number of NumOpens: ", maximum_opens)
# Out:
# Maximum number of NumOpens:  36

# %%
df_emailopened["DateOpened"] = pd.to_datetime(df_emailopened["DateOpened"], format="%d/%m/%Y %H:%M") #convert string to datetime

# %%
df_emailopened["DateOpenedLast"] = pd.to_datetime(df_emailopened["DateOpenedLast"], format="%d/%m/%Y %H:%M") #convert string to datetime

# %%
df_emailopened["EngagementSpan"] = df_emailopened["DateOpenedLast"] - df_emailopened["DateOpened"]
df_emailopened.head(10)
# Out:
#    NumOpens                   Email EmailType          DateOpened  \
# 0         1   ucn1@student.le.ac.uk      Html 2023-10-02 16:34:00
# 1         2  jlpc1@student.le.ac.uk      Html 2023-10-01 17:16:00
# 2         1  jg562@student.le.ac.uk      Html 2023-10-25 17:09:00
# 3         1   vdg2@student.le.ac.uk      Html 2023-09-26 20:58:00
# 4         1  dcc26@student.le.ac.uk      Html 2023-09-26 09:07:00
# 5         2  arc39@student.le.ac.uk      Html 2023-11-08 17:31:00
# 6         2   zgp2@student.le.ac.uk      Html 2023-09-26 13:58:00
# 7         2  shia1@student.le.ac.uk      Html 2023-09-26 09:06:00
# 8         1  jarf1@student.le.ac.uk      Html 2023-09-26 10:25:00
# 9         2  cll46@student.le.ac.uk      Html 2023-09-26 09:13:00
#
#        DateOpenedLast  AverageNumOpens  MinimumOpens  MaximumOpens  \
# 0 2023-10-02 16:34:00         2.129475             1            36
# 1 2023-10-01 17:16:00         2.129475             1            36
# 2 2023-10-25 17:09:00         2.129475             1            36
# 3 2023-09-26 20:58:00         2.129475             1            36
# 4 2023-09-26 09:07:00         2.129475             1            36
# 5 2023-11-14 16:42:00         2.129475             1            36
# 6 2023-09-26 13:58:00         2.129475             1            36
# 7 2023-09-28 12:48:00         2.129475             1            36
# 8 2023-09-26 10:25:00         2.129475             1            36
# 9 2023-09-26 09:20:00         2.129475             1            36
#
#    EngagementSpan
# 0 0 days 00:00:00
# 1 0 days 00:00:00
# 2 0 days 00:00:00
# 3 0 days 00:00:00
# 4 0 days 00:00:00
# 5 5 days 23:11:00
# 6 0 days 00:00:00
# 7 2 days 03:42:00
# 8 0 days 00:00:00
# 9 0 days 00:07:00

# %%
df_emailopened["EngagementHours"] = df_emailopened["EngagementSpan"].dt.total_seconds() / 3600
df_emailopened
# Out:
#        NumOpens                   Email EmailType          DateOpened  \
# 0             1   ucn1@student.le.ac.uk      Html 2023-10-02 16:34:00
# 1             2  jlpc1@student.le.ac.uk      Html 2023-10-01 17:16:00
# 2             1  jg562@student.le.ac.uk      Html 2023-10-25 17:09:00
# 3             1   vdg2@student.le.ac.uk      Html 2023-09-26 20:58:00
# 4             1  dcc26@student.le.ac.uk      Html 2023-09-26 09:07:00
# ...         ...                     ...       ...                 ...
# 12538         4   fama4@leicester.ac.uk      Html 2023-09-26 09:24:00
# 12539         1   ma880@leicester.ac.uk      Html 2023-09-26 14:59:00
# 12540         1   wiha1@leicester.ac.uk      Html 2023-09-26 13:26:00
# 12541        15         advice@le.ac.uk      Html 2023-09-27 11:25:00
# 12542         2     coursereps@le.ac.uk      Html 2023-09-26 09:04:00
#
#            DateOpenedLast  AverageNumOpens  MinimumOpens  MaximumOpens  \
# 0     2023-10-02 16:34:00         2.129475             1            36
# 1     2023-10-01 17:16:00         2.129475             1            36
# 2     2023-10-25 17:09:00         2.129475             1            36
# 3     2023-09-26 20:58:00         2.129475             1            36
# 4     2023-09-26 09:07:00         2.129475             1            36
# ...                   ...              ...           ...           ...
# 12538 2023-09-26 10:43:00         2.129475             1            36
# 12539 2023-09-26 14:59:00         2.129475             1            36
# 12540 2023-09-26 13:26:00         2.129475             1            36
# 12541 2023-09-27 12:51:00         2.129475             1            36
# 12542 2023-09-26 09:05:00         2.129475             1            36
#
#        EngagementSpan  EngagementHours
# 0     0 days 00:00:00         0.000000
# 1     0 days 00:00:00         0.000000
# 2     0 days 00:00:00         0.000000
# 3     0 days 00:00:00         0.000000
# 4     0 days 00:00:00         0.000000
# ...               ...              ...
# 12538 0 days 01:19:00         1.316667
# 12539 0 days 00:00:00         0.000000
# 12540 0 days 00:00:00         0.000000
# 12541 0 days 01:26:00         1.433333
# 12542 0 days 00:01:00         0.016667
#
# [12543 rows x 10 columns]

# %%
def numopen_level_classification(opens): #categorising open levels into different categories
    if opens <= 1:
        return 'Low'
    elif opens <= 4:
        return 'Medium'
    else:
        return 'High'

# %%
df_emailopened["Openlevel"] = df_emailopened["NumOpens"].apply(numopen_level_classification)
df_emailopened
# Out:
#        NumOpens                   Email EmailType          DateOpened  \
# 0             1   ucn1@student.le.ac.uk      Html 2023-10-02 16:34:00
# 1             2  jlpc1@student.le.ac.uk      Html 2023-10-01 17:16:00
# 2             1  jg562@student.le.ac.uk      Html 2023-10-25 17:09:00
# 3             1   vdg2@student.le.ac.uk      Html 2023-09-26 20:58:00
# 4             1  dcc26@student.le.ac.uk      Html 2023-09-26 09:07:00
# ...         ...                     ...       ...                 ...
# 12538         4   fama4@leicester.ac.uk      Html 2023-09-26 09:24:00
# 12539         1   ma880@leicester.ac.uk      Html 2023-09-26 14:59:00
# 12540         1   wiha1@leicester.ac.uk      Html 2023-09-26 13:26:00
# 12541        15         advice@le.ac.uk      Html 2023-09-27 11:25:00
# 12542         2     coursereps@le.ac.uk      Html 2023-09-26 09:04:00
#
#            DateOpenedLast  AverageNumOpens  MinimumOpens  MaximumOpens  \
# 0     2023-10-02 16:34:00         2.129475             1            36
# 1     2023-10-01 17:16:00         2.129475             1            36
# 2     2023-10-25 17:09:00         2.129475             1            36
# 3     2023-09-26 20:58:00         2.129475             1            36
# 4     2023-09-26 09:07:00         2.129475             1            36
# ...                   ...              ...           ...           ...
# 12538 2023-09-26 10:43:00         2.129475             1            36
# 12539 2023-09-26 14:59:00         2.129475             1            36
# 12540 2023-09-26 13:26:00         2.129475             1            36
# 12541 2023-09-27 12:51:00         2.129475             1            36
# 12542 2023-09-26 09:05:00         2.129475             1            36
#
#        EngagementSpan  EngagementHours Openlevel
# 0     0 days 00:00:00         0.000000       Low
# 1     0 days 00:00:00         0.000000    Medium
# 2     0 days 00:00:00         0.000000       Low
# 3     0 days 00:00:00         0.000000       Low
# 4     0 days 00:00:00         0.000000       Low
# ...               ...              ...       ...
# 12538 0 days 01:19:00         1.316667    Medium
# 12539 0 days 00:00:00         0.000000       Low
# 12540 0 days 00:00:00         0.000000       Low
# 12541 0 days 01:26:00         1.433333      High
# 12542 0 days 00:01:00         0.016667    Medium
#
# [12543 rows x 11 columns]

# %%
df_emailopened["Openlevel"].value_counts().plot(kind='bar', title='Email Engagement Levels')
plt.ylabel("Number of People")
plt.show()
df_emailopened["Openlevel"].value_counts()
#high levels of medium open level
#low levels of high open level
# Out:
# Medium    7336
# Low       4521
# High       686
# Name: Openlevel, dtype: int64

# %%
df_emailopened.groupby("EmailType")["AverageNumOpens"].mean().plot(kind="bar", title="Average Opens per Email Type")
plt.ylabel("Average Opens")
plt.show()
df_emailopened.groupby("EmailType")["AverageNumOpens"].value_counts()
# Out:
# EmailType  AverageNumOpens
# Html       2.129475           12543
# Name: AverageNumOpens, dtype: int64

# %%
bins = pd.cut(df_emailopened['EngagementHours'], bins=10).value_counts().sort_index()
print(bins)

df_emailopened['EngagementHours'].plot(kind='hist', bins=10, title='Distribution of Engagement Hours')
plt.show()
# Out:
# (-15.195, 1519.548]       12283
# (1519.548, 3039.097]        103
# (3039.097, 4558.645]         44
# (4558.645, 6078.193]         32
# (6078.193, 7597.742]         23
# (7597.742, 9117.29]          28
# (9117.29, 10636.838]          9
# (10636.838, 12156.387]       13
# (12156.387, 13675.935]        6
# (13675.935, 15195.483]        2
# Name: EngagementHours, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.boxplot(
    x='Openlevel',
    y='EngagementHours',
    data=df_emailopened,
    boxprops=dict(facecolor='white', edgecolor='black'),
    whiskerprops=dict(color='black'),
    capprops=dict(color='black'),
    medianprops=dict(color='black'),
    flierprops=dict(marker='o', color='black', alpha=0.3, markersize=3),
    showfliers=True
)

plt.yscale('log')  #log scale to handle skewed data
plt.title('Engagement Span by Open Level (Log Scale)')
plt.grid(True, which="both", axis='y', linestyle='--', linewidth=0.5)
plt.tight_layout()
plt.show()


sns.boxplot(x='Openlevel', y='EngagementHours', data=df_emailopened).set_title('Engagement Span by Open Level')


df_emailopened.groupby("Openlevel")["EngagementHours"].std()
# Out:
# Openlevel
# High      1684.150744
# Low          0.000000
# Medium     971.915360
# Name: EngagementHours, dtype: float64

# %%
##most and least clicked links

def total_clicks():
    total_clicksdogs = df_clicksdogs["NumClicks"].sum()
    print("Total number of NumClicks for https://www.leicesterunion.com/ents/event/4981/: ", total_clicksdogs)
    
    total_clickssportsfairoadby = df_clickssportsfairoadby["NumClicks"].sum()
    print("Total number of NumClicks for https://le.ac.uk/study/welcome/events: ", total_clickssportsfairoadby)
    

    total_clicksvintagefair = df_clicksvintagefair["NumClicks"].sum()
    print("Total number of NumClicks for https://www.leicesterunion.com/events/6013/4963/: ", total_clicksvintagefair)
    
    


total_clicks()
# Out:
# Total number of NumClicks for https://www.leicesterunion.com/ents/event/4981/:  243
# Total number of NumClicks for https://le.ac.uk/study/welcome/events:  310
# Total number of NumClicks for https://www.leicesterunion.com/events/6013/4963/:  428
